# %%
from graph_transformer_long_range_niches.tl import pad_batch
from graph_transformer_long_range_niches._paths import CFG_FILES, RESULTS, FIG_PATH, LEGNINI23
from graph_transformer_long_range_niches.model import LitGNNTransformer, LitGNNTransformerMasked
from graph_transformer_long_range_niches.modules import LitGCNMasked
from graph_transformer_long_range_niches.pl import CustomColormap, plot_attention_sender_receiver, plot_attention_sender_receiver, SelfAttentionRelevance, calculate_attention, normalized_attention, normalized_class_attention
from graph_transformer_long_range_niches.pp import prepare_geome_dataset, split_adata
from graph_transformer_long_range_niches.config import load_config
from graph_transformer_long_range_niches.tl.geome_dataloader import GraphAnnDataModule

import warnings
warnings.filterwarnings("ignore")

from torch_geometric.loader import DataLoader

from pathlib import Path
import wandb
import torch
import os

## plotting
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import pickle

import scanpy as sc
import squidpy as sq

from sklearn.preprocessing import MinMaxScaler
# Out:
# /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/numba/core/decorators.py:246: RuntimeWarning: nopython is set for njit and is ignored
#   warnings.warn('nopython is set for njit and is ignored', RuntimeWarning)

# %% [markdown]
# # InterScale training
#
#
# 0. Create `config.yaml` file
# 1. Load `cfg` and `adata` object
# 2. Prepare PyG data
# 3. Train GNN (Pre-training)
# 4. Train Transformer (Fine-tuning, global interactions)

# %%
FOLDER = "legnini23"
cfg_path = "/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/Legnini_23/legnini23_InterScale_genes_sample.yaml"

# %% [markdown]
# ### Load config and adata

# %%
cfg = load_config(cfg_path)

# %%
adata = sc.read_h5ad(cfg.dataset.h5ad_data)
adata
# Out:
# AnnData object with n_obs × n_vars = 43762 × 88
#     obs: 'Cell', 'Area', 'x', 'y', 'sample', 'condition', 'organoid', 'obs_names'
#     var: 'gene_ids', 'feature_types'
#     obsm: 'spatial'
#     layers: 'log1p_norm', 'norm_ftsqrt', 'raw'

# %%
adata.X = adata.layers['norm_ftsqrt']

# %%
train_size, val_size, test_size = float(cfg.dataset.train_size), float(cfg.dataset.val_size), float(cfg.dataset.test_size)
print(f'Train size: {train_size}, val size: {val_size} and test size: {test_size}')
# Out:
# Train size: 0.7, val size: 0.2 and test size: 0.1

# %%
split_adata(adata, split_obs=cfg.dataset.obs_split, val_size=val_size, test_size=test_size, seed = cfg.optim.seed, stratify_groups = cfg.dataset.prediction_obs)
# Out:
# Test size > 0
# {'counts': {'train': 23890, 'val': 13228, 'test': 6644}, 'groups': {'train': ['slide1_C2-1', 'slide1_C2-3', 'slide1_C2-5', 'slide4_A2-2', 'slide1_B2-3', 'slide1_A2-1', 'slide4_B2-3', 'slide4_A2-1', 'slide4_A2-3', 'slide1_A2-2', 'slide1_B2-2'], 'val': ['slide4_B2-2', 'slide1_C2-2', 'slide1_D2-3', 'slide1_D2-2'], 'test': ['slide4_B2-1', 'slide1_B2-1']}}
# AnnData object with n_obs × n_vars = 43762 × 88
#     obs: 'Cell', 'Area', 'x', 'y', 'sample', 'condition', 'organoid', 'obs_names', 'split'
#     var: 'gene_ids', 'feature_types'
#     obsm: 'spatial'
#     layers: 'log1p_norm', 'norm_ftsqrt', 'raw'

# %%
pyg_data_list, _ = prepare_geome_dataset(adata, cfg)
pyg_data_list
# Out:
# call new
# call new
# call new
# test
# call new
# [[Data(x=[3023, 88], edge_index=[2, 30734], obs_names=[3023]),
#   Data(x=[1694, 88], edge_index=[2, 19178], obs_names=[1694]),
#   Data(x=[1701, 88], edge_index=[2, 19342], obs_names=[1701]),
#   Data(x=[2241, 88], edge_index=[2, 21678], obs_names=[2241]),
#   Data(x=[2870, 88], edge_index=[2, 31620], obs_names=[2870]),
#   Data(x=[1640, 88], edge_index=[2, 18170], obs_names=[1640]),
#   Data(x=[1958, 88], edge_index=[2, 21830], obs_names=[1958]),
#   Data(x=[2630, 88], edge_index=[2, 22200], obs_names=[2630]),
#   Data(x=[2506, 88], edge_index=[2, 22690], obs_names=[2506]),
#   Data(x=[1984, 88], edge_index=[2, 16736], obs_names=[1984]),
#   Data(x=[1643, 88], edge_index=[2, 13926], obs_names=[1643])],
#  [Data(x=[3510, 88], edge_index=[2, 40186], obs_names=[3510]),
#   Data(x=[4318, 88], edge_index=[2, 48666], obs_names=[4318]),
#   Data(x=[3621, 88], edge_index=[2, 39762], obs_names=[3621]),
#   Data(x=[1779, 88], edge_index=[2, 13146], obs_names=[1779])],
#  [Data(x=[3299, 88], edge_index=[2, 36290], obs_names=[3299]),
#   Data(x=[3345, 88], edge_index=[2, 27630], obs_names=[3345])]]

# %%
train_ds, val_ds, test_ds = pyg_data_list[0], pyg_data_list[1], pyg_data_list[2]

# %%
# set number of classes and number of features
cfg.dataset.merge_from_list(['num_features', len(train_ds[0].x[1])])
if 'classification' in cfg.dataset.prediction_task:
  cfg.dataset.merge_from_list(['num_classes', len(train_ds[0].y[1])])

# %%
dm = GraphAnnDataModule(datas=pyg_data_list, 
                           num_workers=1, 
                           batch_size=int(cfg.dataset.batch_size), 
                           pct_mask_nodes=cfg.dataset.pct_mask_nodes,
                           learning_type="node")
# Out:
# Masked dataloader

# %%
cfg.dataset.batch_size
# Out:
# 2

# %%
model = LitGCNMasked(cfg)
# Out:
# cross-gene correlation metrics

# %%
import math
from pytorch_lightning.callbacks import ModelCheckpoint, LearningRateMonitor, EarlyStopping
import pytorch_lightning as pl

steps_per_epoch = math.ceil(len(train_ds) / cfg.dataset.batch_size)
early_stop_callback = EarlyStopping(monitor="val_r2", min_delta=0.05, patience=10*steps_per_epoch, verbose=False, mode="max")
lr_monitor = LearningRateMonitor(logging_interval='epoch')

# %%
trainer = pl.Trainer(min_epochs=1, 
                     max_epochs=int(cfg.model.n_epochs),
                     enable_progress_bar=True,
                     callbacks=[lr_monitor, early_stop_callback],
                     log_every_n_steps=steps_per_epoch,
                     # Sanity checks: Debugging model
                     #overfit_batches=1,
)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
# from scipy.stats import pearsonr

# y_true = torch.tensor([[ 2.1241, -2.0806,  1.8566, -0.0371], [ 1.0225, -1.8833,  0.9896, -0.4247]])
# y_pred = torch.tensor([[ 2.6982,  6.0981,  1.0000,  1.0000], [11.5823,  3.0387,  1.0000,  1.0000]])

# pearsonr(y_true, y_pred, axis = 1)

# %%
trainer.fit(model, dm)
trainer.validate(model, dm)
# Out:
#   | Name         | Type             | Params | Mode
# ----------------------------------------------------------
# 0 | loss         | GaussianNLLLoss  | 0      | train
# 1 | mse          | MeanSquaredError | 0      | train
# 2 | r2_raw       | R2Score          | 0      | train
# 3 | r2           | R2Score          | 0      | train
# 4 | r2_single    | R2Score          | 0      | train
# 5 | pearson_corr | PearsonCorrCoef  | 0      | train
# 6 | spearman     | SpearmanCorrCoef | 0      | train
# 7 | layers       | ModuleList       | 13.5 K | train
# 8 | out          | Linear           | 1.5 K  | train
# ----------------------------------------------------------
# 15.0 K    Trainable params
# 0         Non-trainable params
# 15.0 K    Total params
# 0.060     Total estimated model params size (MB)
# 17        Modules in train mode
# 0         Modules in eval mode
# Epoch 0:  83%|████████▎ | 5/6 [00:01<00:00,  3.46it/s, v_num=23]           r2:  tensor(-1.2109, grad_fn=<CloneBackward0>) tensor(-1.2109, grad_fn=<MeanBackward0>)
# Epoch 0: 100%|██████████| 6/6 [00:01<00:00,  3.82it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.52it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.49it/s]
# Epoch 1:  83%|████████▎ | 5/6 [00:00<00:00, 10.04it/s, v_num=23]      r2:  tensor(-1.3492, grad_fn=<CloneBackward0>) tensor(-1.3492, grad_fn=<MeanBackward0>)
# Epoch 1: 100%|██████████| 6/6 [00:00<00:00, 11.44it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 13.79it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 14.56it/s]
# Epoch 2:  83%|████████▎ | 5/6 [00:00<00:00,  9.90it/s, v_num=23]      r2:  tensor(-1.1759, grad_fn=<CloneBackward0>) tensor(-1.1759, grad_fn=<MeanBackward0>)
# Epoch 2: 100%|██████████| 6/6 [00:00<00:00, 11.34it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.06it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.47it/s]
# Epoch 3:  83%|████████▎ | 5/6 [00:00<00:00,  9.67it/s, v_num=23]      r2:  tensor(-1.0703, grad_fn=<CloneBackward0>) tensor(-1.0703, grad_fn=<MeanBackward0>)
# Epoch 3: 100%|██████████| 6/6 [00:00<00:00, 11.14it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.55it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.77it/s]
# Epoch 4:  83%|████████▎ | 5/6 [00:00<00:00, 10.07it/s, v_num=23]      r2:  tensor(-1.0344, grad_fn=<CloneBackward0>) tensor(-1.0344, grad_fn=<MeanBackward0>)
# Epoch 4: 100%|██████████| 6/6 [00:00<00:00, 11.55it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.70it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.87it/s]
# Epoch 5:  83%|████████▎ | 5/6 [00:00<00:00,  9.40it/s, v_num=23]      r2:  tensor(-0.7500, grad_fn=<CloneBackward0>) tensor(-0.7500, grad_fn=<MeanBackward0>)
# Epoch 5: 100%|██████████| 6/6 [00:00<00:00, 10.84it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.54it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.30it/s]
# Epoch 6:  83%|████████▎ | 5/6 [00:00<00:00,  9.82it/s, v_num=23]      r2:  tensor(-0.7035, grad_fn=<CloneBackward0>) tensor(-0.7035, grad_fn=<MeanBackward0>)
# Epoch 6: 100%|██████████| 6/6 [00:00<00:00, 11.32it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.53it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.42it/s]
# Epoch 7:  83%|████████▎ | 5/6 [00:00<00:00,  8.99it/s, v_num=23]      r2:  tensor(-0.6848, grad_fn=<CloneBackward0>) tensor(-0.6848, grad_fn=<MeanBackward0>)
# Epoch 7: 100%|██████████| 6/6 [00:00<00:00, 10.34it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.25it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.87it/s]
# Epoch 8:  83%|████████▎ | 5/6 [00:00<00:00,  9.51it/s, v_num=23]      r2:  tensor(-0.9652, grad_fn=<CloneBackward0>) tensor(-0.9652, grad_fn=<MeanBackward0>)
# Epoch 8: 100%|██████████| 6/6 [00:00<00:00, 10.98it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.55it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.72it/s]
# Epoch 9:  83%|████████▎ | 5/6 [00:00<00:00, 10.49it/s, v_num=23]      r2:  tensor(-0.9298, grad_fn=<CloneBackward0>) tensor(-0.9298, grad_fn=<MeanBackward0>)
# Epoch 9: 100%|██████████| 6/6 [00:00<00:00, 12.01it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.28it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.10it/s]
# Epoch 10:  83%|████████▎ | 5/6 [00:00<00:00, 10.15it/s, v_num=23]     r2:  tensor(-1.1187, grad_fn=<CloneBackward0>) tensor(-1.1187, grad_fn=<MeanBackward0>)
# Epoch 10: 100%|██████████| 6/6 [00:00<00:00, 11.52it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.88it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.34it/s]
# Epoch 11:  83%|████████▎ | 5/6 [00:00<00:00, 10.51it/s, v_num=23]     r2:  tensor(-0.2759, grad_fn=<CloneBackward0>) tensor(-0.2759, grad_fn=<MeanBackward0>)
# Epoch 11: 100%|██████████| 6/6 [00:00<00:00, 11.94it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.88it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.38it/s]
# Epoch 12:  83%|████████▎ | 5/6 [00:00<00:00,  8.93it/s, v_num=23]     r2:  tensor(-0.8497, grad_fn=<CloneBackward0>) tensor(-0.8497, grad_fn=<MeanBackward0>)
# Epoch 12: 100%|██████████| 6/6 [00:00<00:00, 10.30it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.68it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.99it/s]
# Epoch 13:  83%|████████▎ | 5/6 [00:00<00:00,  9.56it/s, v_num=23]     r2:  tensor(-0.5847, grad_fn=<CloneBackward0>) tensor(-0.5847, grad_fn=<MeanBackward0>)
# Epoch 13: 100%|██████████| 6/6 [00:00<00:00, 10.99it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.00it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.42it/s]
# Epoch 14:  83%|████████▎ | 5/6 [00:00<00:00, 10.19it/s, v_num=23]     r2:  tensor(-0.7059, grad_fn=<CloneBackward0>) tensor(-0.7059, grad_fn=<MeanBackward0>)
# Epoch 14: 100%|██████████| 6/6 [00:00<00:00, 11.57it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.00it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 14.01it/s]
# Epoch 15:  83%|████████▎ | 5/6 [00:00<00:00,  9.14it/s, v_num=23]     r2:  tensor(-0.9770, grad_fn=<CloneBackward0>) tensor(-0.9770, grad_fn=<MeanBackward0>)
# Epoch 15: 100%|██████████| 6/6 [00:00<00:00, 10.45it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.16it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.88it/s]
# Epoch 16:  83%|████████▎ | 5/6 [00:00<00:00, 10.50it/s, v_num=23]     r2:  tensor(-0.6409, grad_fn=<CloneBackward0>) tensor(-0.6409, grad_fn=<MeanBackward0>)
# Epoch 16: 100%|██████████| 6/6 [00:00<00:00, 11.90it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.22it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.94it/s]
# Epoch 17:  83%|████████▎ | 5/6 [00:00<00:00,  9.87it/s, v_num=23]     r2:  tensor(-0.8303, grad_fn=<CloneBackward0>) tensor(-0.8303, grad_fn=<MeanBackward0>)
# Epoch 17: 100%|██████████| 6/6 [00:00<00:00, 11.34it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  9.99it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.57it/s]
# Epoch 18:  83%|████████▎ | 5/6 [00:00<00:00, 10.22it/s, v_num=23]     r2:  tensor(-0.6233, grad_fn=<CloneBackward0>) tensor(-0.6233, grad_fn=<MeanBackward0>)
# Epoch 18: 100%|██████████| 6/6 [00:00<00:00, 11.77it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.75it/s]
# Epoch 19:  83%|████████▎ | 5/6 [00:00<00:00, 10.05it/s, v_num=23]     r2:  tensor(-0.0753, grad_fn=<CloneBackward0>) tensor(-0.0753, grad_fn=<MeanBackward0>)
# Epoch 19: 100%|██████████| 6/6 [00:00<00:00, 11.46it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.84it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.24it/s]
# Epoch 20:  83%|████████▎ | 5/6 [00:00<00:00,  9.16it/s, v_num=23]     r2:  tensor(-0.4911, grad_fn=<CloneBackward0>) tensor(-0.4911, grad_fn=<MeanBackward0>)
# Epoch 20: 100%|██████████| 6/6 [00:00<00:00, 10.54it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.17it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.20it/s]
# Epoch 21:  83%|████████▎ | 5/6 [00:00<00:00, 10.58it/s, v_num=23]     r2:  tensor(0.0052, grad_fn=<CloneBackward0>) tensor(0.0052, grad_fn=<MeanBackward0>)
# Epoch 21: 100%|██████████| 6/6 [00:00<00:00, 12.09it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.12it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.10it/s]
# Epoch 22:  83%|████████▎ | 5/6 [00:00<00:00, 10.34it/s, v_num=23]     r2:  tensor(-0.3549, grad_fn=<CloneBackward0>) tensor(-0.3549, grad_fn=<MeanBackward0>)
# Epoch 22: 100%|██████████| 6/6 [00:00<00:00, 11.84it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.95it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.72it/s]
# Epoch 23:  83%|████████▎ | 5/6 [00:00<00:00,  9.92it/s, v_num=23]     r2:  tensor(-0.1657, grad_fn=<CloneBackward0>) tensor(-0.1657, grad_fn=<MeanBackward0>)
# Epoch 23: 100%|██████████| 6/6 [00:00<00:00, 11.43it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.09it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.25it/s]
# Epoch 24:  83%|████████▎ | 5/6 [00:00<00:00,  9.04it/s, v_num=23]     r2:  tensor(-0.1259, grad_fn=<CloneBackward0>) tensor(-0.1259, grad_fn=<MeanBackward0>)
# Epoch 24: 100%|██████████| 6/6 [00:00<00:00, 10.40it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.91it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.84it/s]
# Epoch 25:  83%|████████▎ | 5/6 [00:00<00:00, 10.53it/s, v_num=23]     r2:  tensor(0.1535, grad_fn=<CloneBackward0>) tensor(0.1535, grad_fn=<MeanBackward0>)
# Epoch 25: 100%|██████████| 6/6 [00:00<00:00, 12.08it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.56it/s]
# Epoch 26:  83%|████████▎ | 5/6 [00:00<00:00, 10.30it/s, v_num=23]     r2:  tensor(0.2433, grad_fn=<CloneBackward0>) tensor(0.2433, grad_fn=<MeanBackward0>)
# Epoch 26: 100%|██████████| 6/6 [00:00<00:00, 11.83it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.65it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.44it/s]
# Epoch 27:  83%|████████▎ | 5/6 [00:00<00:00,  9.41it/s, v_num=23]     r2:  tensor(0.3446, grad_fn=<CloneBackward0>) tensor(0.3446, grad_fn=<MeanBackward0>)
# Epoch 27: 100%|██████████| 6/6 [00:00<00:00, 10.79it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.21it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.21it/s]
# Epoch 28:  83%|████████▎ | 5/6 [00:00<00:00,  9.37it/s, v_num=23]     r2:  tensor(0.3861, grad_fn=<CloneBackward0>) tensor(0.3861, grad_fn=<MeanBackward0>)
# Epoch 28: 100%|██████████| 6/6 [00:00<00:00, 10.74it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.45it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.70it/s]
# Epoch 29:  83%|████████▎ | 5/6 [00:00<00:00, 10.45it/s, v_num=23]     r2:  tensor(0.5027, grad_fn=<CloneBackward0>) tensor(0.5027, grad_fn=<MeanBackward0>)
# Epoch 29: 100%|██████████| 6/6 [00:00<00:00, 11.91it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.11it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.89it/s]
# Epoch 30:  83%|████████▎ | 5/6 [00:00<00:00,  9.92it/s, v_num=23]     r2:  tensor(0.5855, grad_fn=<CloneBackward0>) tensor(0.5855, grad_fn=<MeanBackward0>)
# Epoch 30: 100%|██████████| 6/6 [00:00<00:00, 11.43it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.03it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.13it/s]
# Epoch 31:  83%|████████▎ | 5/6 [00:00<00:00, 10.70it/s, v_num=23]     r2:  tensor(0.7130, grad_fn=<CloneBackward0>) tensor(0.7130, grad_fn=<MeanBackward0>)
# Epoch 31: 100%|██████████| 6/6 [00:00<00:00, 12.14it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.20it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.32it/s]
# Epoch 32:  83%|████████▎ | 5/6 [00:00<00:00,  9.30it/s, v_num=23]     r2:  tensor(0.6969, grad_fn=<CloneBackward0>) tensor(0.6969, grad_fn=<MeanBackward0>)
# Epoch 32: 100%|██████████| 6/6 [00:00<00:00, 10.67it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.11it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.17it/s]
# Epoch 33:  83%|████████▎ | 5/6 [00:00<00:00, 10.47it/s, v_num=23]     r2:  tensor(0.5757, grad_fn=<CloneBackward0>) tensor(0.5757, grad_fn=<MeanBackward0>)
# Epoch 33: 100%|██████████| 6/6 [00:00<00:00, 11.90it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.93it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.07it/s]
# Epoch 34:  83%|████████▎ | 5/6 [00:00<00:00,  9.11it/s, v_num=23]     r2:  tensor(0.4537, grad_fn=<CloneBackward0>) tensor(0.4537, grad_fn=<MeanBackward0>)
# Epoch 34: 100%|██████████| 6/6 [00:00<00:00, 10.48it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.66it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.29it/s]
# Epoch 35:  83%|████████▎ | 5/6 [00:00<00:00,  9.76it/s, v_num=23]     r2:  tensor(0.7939, grad_fn=<CloneBackward0>) tensor(0.7939, grad_fn=<MeanBackward0>)
# Epoch 35: 100%|██████████| 6/6 [00:00<00:00, 11.16it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.43it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.65it/s]
# Epoch 36:  83%|████████▎ | 5/6 [00:00<00:00, 10.17it/s, v_num=23]     r2:  tensor(0.4652, grad_fn=<CloneBackward0>) tensor(0.4652, grad_fn=<MeanBackward0>)
# Epoch 36: 100%|██████████| 6/6 [00:00<00:00, 11.58it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.34it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.59it/s]
# Epoch 37:  83%|████████▎ | 5/6 [00:00<00:00,  9.85it/s, v_num=23]     r2:  tensor(0.6169, grad_fn=<CloneBackward0>) tensor(0.6169, grad_fn=<MeanBackward0>)
# Epoch 37: 100%|██████████| 6/6 [00:00<00:00, 11.21it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.57it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.84it/s]
# Epoch 38:  83%|████████▎ | 5/6 [00:00<00:00, 10.42it/s, v_num=23]     r2:  tensor(0.8289, grad_fn=<CloneBackward0>) tensor(0.8289, grad_fn=<MeanBackward0>)
# Epoch 38: 100%|██████████| 6/6 [00:00<00:00, 11.91it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.24it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.34it/s]
# Epoch 39:  83%|████████▎ | 5/6 [00:00<00:00,  9.64it/s, v_num=23]     r2:  tensor(0.8178, grad_fn=<CloneBackward0>) tensor(0.8178, grad_fn=<MeanBackward0>)
# Epoch 39: 100%|██████████| 6/6 [00:00<00:00, 11.07it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.13it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.87it/s]
# Epoch 40:  83%|████████▎ | 5/6 [00:00<00:00,  9.18it/s, v_num=23]     r2:  tensor(0.5498, grad_fn=<CloneBackward0>) tensor(0.5498, grad_fn=<MeanBackward0>)
# Epoch 40: 100%|██████████| 6/6 [00:00<00:00, 10.58it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.96it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.00it/s]
# Epoch 41:  83%|████████▎ | 5/6 [00:00<00:00,  8.63it/s, v_num=23]     r2:  tensor(0.7088, grad_fn=<CloneBackward0>) tensor(0.7088, grad_fn=<MeanBackward0>)
# Epoch 41: 100%|██████████| 6/6 [00:00<00:00,  9.95it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.81it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.84it/s]
# Epoch 42:  83%|████████▎ | 5/6 [00:00<00:00, 10.15it/s, v_num=23]     r2:  tensor(0.6878, grad_fn=<CloneBackward0>) tensor(0.6878, grad_fn=<MeanBackward0>)
# Epoch 42: 100%|██████████| 6/6 [00:00<00:00, 11.62it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.09it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.90it/s]
# Epoch 43:  83%|████████▎ | 5/6 [00:00<00:00,  9.97it/s, v_num=23]     r2:  tensor(0.7693, grad_fn=<CloneBackward0>) tensor(0.7693, grad_fn=<MeanBackward0>)
# Epoch 43: 100%|██████████| 6/6 [00:00<00:00, 11.45it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.86it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.09it/s]
# Epoch 44:  83%|████████▎ | 5/6 [00:00<00:00,  8.95it/s, v_num=23]     r2:  tensor(0.7132, grad_fn=<CloneBackward0>) tensor(0.7132, grad_fn=<MeanBackward0>)
# Epoch 44: 100%|██████████| 6/6 [00:00<00:00, 10.30it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.75it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.75it/s]
# Epoch 45:  83%|████████▎ | 5/6 [00:00<00:00, 10.20it/s, v_num=23]     r2:  tensor(0.8239, grad_fn=<CloneBackward0>) tensor(0.8239, grad_fn=<MeanBackward0>)
# Epoch 45: 100%|██████████| 6/6 [00:00<00:00, 11.66it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.95it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.01it/s]
# Epoch 46:  83%|████████▎ | 5/6 [00:00<00:00, 10.31it/s, v_num=23]     r2:  tensor(0.8243, grad_fn=<CloneBackward0>) tensor(0.8243, grad_fn=<MeanBackward0>)
# Epoch 46: 100%|██████████| 6/6 [00:00<00:00, 11.85it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.23it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.21it/s]
# Epoch 47:  83%|████████▎ | 5/6 [00:00<00:00,  9.65it/s, v_num=23]     r2:  tensor(0.8025, grad_fn=<CloneBackward0>) tensor(0.8025, grad_fn=<MeanBackward0>)
# Epoch 47: 100%|██████████| 6/6 [00:00<00:00, 11.11it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.39it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.40it/s]
# Epoch 48:  83%|████████▎ | 5/6 [00:00<00:00, 10.20it/s, v_num=23]     r2:  tensor(0.8487, grad_fn=<CloneBackward0>) tensor(0.8487, grad_fn=<MeanBackward0>)
# Epoch 48: 100%|██████████| 6/6 [00:00<00:00, 11.73it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.30it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.76it/s]
# Epoch 49:  83%|████████▎ | 5/6 [00:00<00:00,  9.67it/s, v_num=23]     r2:  tensor(0.7016, grad_fn=<CloneBackward0>) tensor(0.7016, grad_fn=<MeanBackward0>)
# Epoch 49: 100%|██████████| 6/6 [00:00<00:00, 11.15it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.14it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.33it/s]
# Epoch 50:  83%|████████▎ | 5/6 [00:00<00:00,  9.31it/s, v_num=23]     r2:  tensor(0.8298, grad_fn=<CloneBackward0>) tensor(0.8298, grad_fn=<MeanBackward0>)
# Epoch 50: 100%|██████████| 6/6 [00:00<00:00, 10.68it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.66it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.75it/s]
# Epoch 51:  83%|████████▎ | 5/6 [00:00<00:00,  9.05it/s, v_num=23]     r2:  tensor(0.7899, grad_fn=<CloneBackward0>) tensor(0.7899, grad_fn=<MeanBackward0>)
# Epoch 51: 100%|██████████| 6/6 [00:00<00:00, 10.41it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.38it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.79it/s]
# Epoch 52:  83%|████████▎ | 5/6 [00:00<00:00,  9.63it/s, v_num=23]     r2:  tensor(0.8588, grad_fn=<CloneBackward0>) tensor(0.8588, grad_fn=<MeanBackward0>)
# Epoch 52: 100%|██████████| 6/6 [00:00<00:00, 11.04it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.38it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.14it/s]
# Epoch 53:  83%|████████▎ | 5/6 [00:00<00:00,  9.29it/s, v_num=23]     r2:  tensor(0.4673, grad_fn=<CloneBackward0>) tensor(0.4673, grad_fn=<MeanBackward0>)
# Epoch 53: 100%|██████████| 6/6 [00:00<00:00, 10.69it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.74it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.40it/s]
# Epoch 54:  83%|████████▎ | 5/6 [00:00<00:00, 10.50it/s, v_num=23]     r2:  tensor(0.7049, grad_fn=<CloneBackward0>) tensor(0.7049, grad_fn=<MeanBackward0>)
# Epoch 54: 100%|██████████| 6/6 [00:00<00:00, 11.98it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.51it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.88it/s]
# Epoch 55:  83%|████████▎ | 5/6 [00:00<00:00,  9.28it/s, v_num=23]     r2:  tensor(0.7989, grad_fn=<CloneBackward0>) tensor(0.7989, grad_fn=<MeanBackward0>)
# Epoch 55: 100%|██████████| 6/6 [00:00<00:00, 10.75it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.66it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.31it/s]
# Epoch 56:  83%|████████▎ | 5/6 [00:00<00:00, 10.06it/s, v_num=23]     r2:  tensor(0.4818, grad_fn=<CloneBackward0>) tensor(0.4818, grad_fn=<MeanBackward0>)
# Epoch 56: 100%|██████████| 6/6 [00:00<00:00, 11.52it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.15it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.67it/s]
# Epoch 57:  83%|████████▎ | 5/6 [00:00<00:00, 10.46it/s, v_num=23]     r2:  tensor(0.8322, grad_fn=<CloneBackward0>) tensor(0.8322, grad_fn=<MeanBackward0>)
# Epoch 57: 100%|██████████| 6/6 [00:00<00:00, 12.00it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.84it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.95it/s]
# Epoch 58:  83%|████████▎ | 5/6 [00:00<00:00,  9.68it/s, v_num=23]     r2:  tensor(0.8319, grad_fn=<CloneBackward0>) tensor(0.8319, grad_fn=<MeanBackward0>)
# Epoch 58: 100%|██████████| 6/6 [00:00<00:00, 11.10it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.39it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.67it/s]
# Epoch 59:  83%|████████▎ | 5/6 [00:00<00:00,  9.23it/s, v_num=23]     r2:  tensor(0.7017, grad_fn=<CloneBackward0>) tensor(0.7017, grad_fn=<MeanBackward0>)
# Epoch 59: 100%|██████████| 6/6 [00:00<00:00, 10.56it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  9.48it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.26it/s]
# Epoch 60:  83%|████████▎ | 5/6 [00:00<00:00,  9.60it/s, v_num=23]     r2:  tensor(0.7467, grad_fn=<CloneBackward0>) tensor(0.7467, grad_fn=<MeanBackward0>)
# Epoch 60: 100%|██████████| 6/6 [00:00<00:00, 11.01it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.88it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 13.11it/s]
# Epoch 61:  83%|████████▎ | 5/6 [00:00<00:00,  9.60it/s, v_num=23]     r2:  tensor(0.8125, grad_fn=<CloneBackward0>) tensor(0.8125, grad_fn=<MeanBackward0>)
# Epoch 61: 100%|██████████| 6/6 [00:00<00:00, 11.09it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.04it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.65it/s]
# Epoch 62:  83%|████████▎ | 5/6 [00:00<00:00,  9.51it/s, v_num=23]     r2:  tensor(0.7277, grad_fn=<CloneBackward0>) tensor(0.7277, grad_fn=<MeanBackward0>)
# Epoch 62: 100%|██████████| 6/6 [00:00<00:00, 10.96it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.72it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.91it/s]
# Epoch 63:  83%|████████▎ | 5/6 [00:00<00:00, 10.10it/s, v_num=23]     r2:  tensor(0.4847, grad_fn=<CloneBackward0>) tensor(0.4847, grad_fn=<MeanBackward0>)
# Epoch 63: 100%|██████████| 6/6 [00:00<00:00, 11.56it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.87it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.16it/s]
# Epoch 64:  83%|████████▎ | 5/6 [00:00<00:00,  9.22it/s, v_num=23]     r2:  tensor(0.7314, grad_fn=<CloneBackward0>) tensor(0.7314, grad_fn=<MeanBackward0>)
# Epoch 64: 100%|██████████| 6/6 [00:00<00:00, 10.57it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.77it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.03it/s]
# Epoch 65:  83%|████████▎ | 5/6 [00:00<00:00,  9.62it/s, v_num=23]     r2:  tensor(0.6250, grad_fn=<CloneBackward0>) tensor(0.6250, grad_fn=<MeanBackward0>)
# Epoch 65: 100%|██████████| 6/6 [00:00<00:00, 11.04it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.51it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.37it/s]
# Epoch 66:  83%|████████▎ | 5/6 [00:00<00:00,  9.56it/s, v_num=23]     r2:  tensor(0.8534, grad_fn=<CloneBackward0>) tensor(0.8534, grad_fn=<MeanBackward0>)
# Epoch 66: 100%|██████████| 6/6 [00:00<00:00, 10.96it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.33it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.87it/s]
# Epoch 67:  83%|████████▎ | 5/6 [00:00<00:00,  9.67it/s, v_num=23]     r2:  tensor(0.7627, grad_fn=<CloneBackward0>) tensor(0.7627, grad_fn=<MeanBackward0>)
# Epoch 67: 100%|██████████| 6/6 [00:00<00:00, 11.11it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.83it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.30it/s]
# Epoch 68:  83%|████████▎ | 5/6 [00:00<00:00,  9.75it/s, v_num=23]     r2:  tensor(0.8028, grad_fn=<CloneBackward0>) tensor(0.8028, grad_fn=<MeanBackward0>)
# Epoch 68: 100%|██████████| 6/6 [00:00<00:00, 11.23it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.21it/s]
# Epoch 69:  83%|████████▎ | 5/6 [00:00<00:00,  8.62it/s, v_num=23]     r2:  tensor(0.7695, grad_fn=<CloneBackward0>) tensor(0.7695, grad_fn=<MeanBackward0>)
# Epoch 69: 100%|██████████| 6/6 [00:00<00:00,  9.92it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.51it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.21it/s]
# Epoch 70:  83%|████████▎ | 5/6 [00:00<00:00,  9.90it/s, v_num=23]     r2:  tensor(0.7650, grad_fn=<CloneBackward0>) tensor(0.7650, grad_fn=<MeanBackward0>)
# Epoch 70: 100%|██████████| 6/6 [00:00<00:00, 11.38it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.26it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.08it/s]
# Epoch 71:  83%|████████▎ | 5/6 [00:00<00:00,  5.51it/s, v_num=23]     r2:  tensor(0.8184, grad_fn=<CloneBackward0>) tensor(0.8184, grad_fn=<MeanBackward0>)
# Epoch 71: 100%|██████████| 6/6 [00:00<00:00,  6.46it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.82it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.03it/s]
# Epoch 72:  83%|████████▎ | 5/6 [00:00<00:00,  9.83it/s, v_num=23]     r2:  tensor(0.4886, grad_fn=<CloneBackward0>) tensor(0.4886, grad_fn=<MeanBackward0>)
# Epoch 72: 100%|██████████| 6/6 [00:00<00:00, 11.22it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  7.44it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  9.50it/s]
# Epoch 73:  83%|████████▎ | 5/6 [00:00<00:00,  9.09it/s, v_num=23]     r2:  tensor(0.7680, grad_fn=<CloneBackward0>) tensor(0.7680, grad_fn=<MeanBackward0>)
# Epoch 73: 100%|██████████| 6/6 [00:00<00:00, 10.42it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.66it/s]
# Epoch 74:  83%|████████▎ | 5/6 [00:00<00:00,  9.75it/s, v_num=23]     r2:  tensor(0.7926, grad_fn=<CloneBackward0>) tensor(0.7926, grad_fn=<MeanBackward0>)
# Epoch 74: 100%|██████████| 6/6 [00:00<00:00, 11.16it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.92it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.90it/s]
# Epoch 75:  83%|████████▎ | 5/6 [00:00<00:00,  8.69it/s, v_num=23]     r2:  tensor(0.7826, grad_fn=<CloneBackward0>) tensor(0.7826, grad_fn=<MeanBackward0>)
# Epoch 75: 100%|██████████| 6/6 [00:00<00:00,  9.94it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  9.50it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.53it/s]
# Epoch 76:  83%|████████▎ | 5/6 [00:00<00:00,  9.35it/s, v_num=23]     r2:  tensor(0.4899, grad_fn=<CloneBackward0>) tensor(0.4899, grad_fn=<MeanBackward0>)
# Epoch 76: 100%|██████████| 6/6 [00:00<00:00, 10.62it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.00it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.76it/s]
# Epoch 77:  83%|████████▎ | 5/6 [00:00<00:00,  9.17it/s, v_num=23]     r2:  tensor(0.8040, grad_fn=<CloneBackward0>) tensor(0.8040, grad_fn=<MeanBackward0>)
# Epoch 77: 100%|██████████| 6/6 [00:00<00:00, 10.52it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.46it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.20it/s]
# Epoch 78:  83%|████████▎ | 5/6 [00:00<00:00,  9.50it/s, v_num=23]     r2:  tensor(0.6834, grad_fn=<CloneBackward0>) tensor(0.6834, grad_fn=<MeanBackward0>)
# Epoch 78: 100%|██████████| 6/6 [00:00<00:00, 10.77it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.60it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.83it/s]
# Epoch 79:  83%|████████▎ | 5/6 [00:00<00:00,  9.70it/s, v_num=23]     r2:  tensor(0.7471, grad_fn=<CloneBackward0>) tensor(0.7471, grad_fn=<MeanBackward0>)
# Epoch 79: 100%|██████████| 6/6 [00:00<00:00, 11.11it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.56it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.53it/s]
# Epoch 80:  83%|████████▎ | 5/6 [00:00<00:00,  9.56it/s, v_num=23]     r2:  tensor(0.8035, grad_fn=<CloneBackward0>) tensor(0.8035, grad_fn=<MeanBackward0>)
# Epoch 80: 100%|██████████| 6/6 [00:00<00:00, 10.89it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.54it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.19it/s]
# Epoch 81:  83%|████████▎ | 5/6 [00:00<00:00,  9.83it/s, v_num=23]     r2:  tensor(0.8660, grad_fn=<CloneBackward0>) tensor(0.8660, grad_fn=<MeanBackward0>)
# Epoch 81: 100%|██████████| 6/6 [00:00<00:00, 11.05it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.08it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.00it/s]
# Epoch 82:  83%|████████▎ | 5/6 [00:00<00:00,  9.64it/s, v_num=23]     r2:  tensor(0.7138, grad_fn=<CloneBackward0>) tensor(0.7138, grad_fn=<MeanBackward0>)
# Epoch 82: 100%|██████████| 6/6 [00:00<00:00, 10.96it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.40it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.49it/s]
# Epoch 83:  83%|████████▎ | 5/6 [00:00<00:00,  8.86it/s, v_num=23]     r2:  tensor(0.8239, grad_fn=<CloneBackward0>) tensor(0.8239, grad_fn=<MeanBackward0>)
# Epoch 83: 100%|██████████| 6/6 [00:00<00:00, 10.22it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  9.50it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.09it/s]
# Epoch 84:  83%|████████▎ | 5/6 [00:00<00:00,  8.82it/s, v_num=23]     r2:  tensor(0.8144, grad_fn=<CloneBackward0>) tensor(0.8144, grad_fn=<MeanBackward0>)
# Epoch 84: 100%|██████████| 6/6 [00:00<00:00, 10.20it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.09it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.34it/s]
# Epoch 85:  83%|████████▎ | 5/6 [00:00<00:00,  9.00it/s, v_num=23]     r2:  tensor(0.8701, grad_fn=<CloneBackward0>) tensor(0.8701, grad_fn=<MeanBackward0>)
# Epoch 85: 100%|██████████| 6/6 [00:00<00:00, 10.30it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.25it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.04it/s]
# Epoch 86:  83%|████████▎ | 5/6 [00:00<00:00,  9.84it/s, v_num=23]     r2:  tensor(0.8687, grad_fn=<CloneBackward0>) tensor(0.8687, grad_fn=<MeanBackward0>)
# Epoch 86: 100%|██████████| 6/6 [00:00<00:00, 11.28it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  9.23it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.40it/s]
# Epoch 87:  83%|████████▎ | 5/6 [00:00<00:00,  8.73it/s, v_num=23]     r2:  tensor(0.8792, grad_fn=<CloneBackward0>) tensor(0.8792, grad_fn=<MeanBackward0>)
# Epoch 87: 100%|██████████| 6/6 [00:00<00:00,  9.96it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  9.77it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.47it/s]
# Epoch 88:  83%|████████▎ | 5/6 [00:00<00:00,  8.93it/s, v_num=23]     r2:  tensor(0.8123, grad_fn=<CloneBackward0>) tensor(0.8123, grad_fn=<MeanBackward0>)
# Epoch 88: 100%|██████████| 6/6 [00:00<00:00, 10.20it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  8.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 10.63it/s]
# Epoch 89:  83%|████████▎ | 5/6 [00:00<00:00,  9.54it/s, v_num=23]     r2:  tensor(0.8881, grad_fn=<CloneBackward0>) tensor(0.8881, grad_fn=<MeanBackward0>)
# Epoch 89: 100%|██████████| 6/6 [00:00<00:00, 10.88it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.98it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.33it/s]
# ...
# Epoch 105: 100%|██████████| 6/6 [00:00<00:00, 10.13it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  8.71it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 10.36it/s]
# Epoch 106:  83%|████████▎ | 5/6 [00:00<00:00,  8.82it/s, v_num=23]    r2:  tensor(0.8687, grad_fn=<CloneBackward0>) tensor(0.8687, grad_fn=<MeanBackward0>)
# Epoch 106: 100%|██████████| 6/6 [00:00<00:00, 10.18it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  9.54it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.63it/s]
# Epoch 107:  83%|████████▎ | 5/6 [00:00<00:00,  9.02it/s, v_num=23]    r2:  tensor(0.8468, grad_fn=<CloneBackward0>) tensor(0.8468, grad_fn=<MeanBackward0>)
# Epoch 107: 100%|██████████| 6/6 [00:00<00:00, 10.31it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  9.77it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 10.83it/s]
# Epoch 108:  83%|████████▎ | 5/6 [00:00<00:00,  8.92it/s, v_num=23]    r2:  tensor(0.8764, grad_fn=<CloneBackward0>) tensor(0.8764, grad_fn=<MeanBackward0>)
# Epoch 108: 100%|██████████| 6/6 [00:00<00:00, 10.22it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  9.22it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.43it/s]
# Epoch 109:  83%|████████▎ | 5/6 [00:00<00:00,  8.17it/s, v_num=23]    r2:  tensor(0.8488, grad_fn=<CloneBackward0>) tensor(0.8488, grad_fn=<MeanBackward0>)
# Epoch 109: 100%|██████████| 6/6 [00:00<00:00,  9.38it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 11.27it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 12.20it/s]
# Epoch 110:  83%|████████▎ | 5/6 [00:00<00:00,  9.40it/s, v_num=23]    r2:  tensor(0.8846, grad_fn=<CloneBackward0>) tensor(0.8846, grad_fn=<MeanBackward0>)
# Epoch 110: 100%|██████████| 6/6 [00:00<00:00, 10.74it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.93it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.93it/s]
# Epoch 111:  83%|████████▎ | 5/6 [00:00<00:00,  9.22it/s, v_num=23]    r2:  tensor(0.8336, grad_fn=<CloneBackward0>) tensor(0.8336, grad_fn=<MeanBackward0>)
# Epoch 111: 100%|██████████| 6/6 [00:00<00:00, 10.64it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.77it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.24it/s]
# Epoch 112:  83%|████████▎ | 5/6 [00:00<00:00,  9.20it/s, v_num=23]    r2:  tensor(0.8153, grad_fn=<CloneBackward0>) tensor(0.8153, grad_fn=<MeanBackward0>)
# Epoch 112: 100%|██████████| 6/6 [00:00<00:00, 10.57it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 12.10it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.77it/s]
# Epoch 113:  83%|████████▎ | 5/6 [00:00<00:00,  9.36it/s, v_num=23]    r2:  tensor(0.8915, grad_fn=<CloneBackward0>) tensor(0.8915, grad_fn=<MeanBackward0>)
# Epoch 113: 100%|██████████| 6/6 [00:00<00:00, 10.76it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  7.33it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00,  9.41it/s]
# Epoch 114:  83%|████████▎ | 5/6 [00:00<00:00,  8.24it/s, v_num=23]    r2:  tensor(0.8904, grad_fn=<CloneBackward0>) tensor(0.8904, grad_fn=<MeanBackward0>)
# Epoch 114: 100%|██████████| 6/6 [00:00<00:00,  9.47it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00,  9.55it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 10.79it/s]
# Epoch 115:  83%|████████▎ | 5/6 [00:00<00:00,  8.03it/s, v_num=23]    r2:  tensor(0.8440, grad_fn=<CloneBackward0>) tensor(0.8440, grad_fn=<MeanBackward0>)
# Epoch 115: 100%|██████████| 6/6 [00:00<00:00,  9.26it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.58it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.81it/s]
# Epoch 116:  83%|████████▎ | 5/6 [00:00<00:00,  8.92it/s, v_num=23]    r2:  tensor(0.8949, grad_fn=<CloneBackward0>) tensor(0.8949, grad_fn=<MeanBackward0>)
# Epoch 116: 100%|██████████| 6/6 [00:00<00:00, 10.28it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.40it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.16it/s]
# Epoch 117:  83%|████████▎ | 5/6 [00:00<00:00,  8.60it/s, v_num=23]    r2:  tensor(0.9010, grad_fn=<CloneBackward0>) tensor(0.9010, grad_fn=<MeanBackward0>)
# Epoch 117: 100%|██████████| 6/6 [00:00<00:00,  9.89it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 10.91it/s]
# Validation DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 11.78it/s]
# Epoch 118:  83%|████████▎ | 5/6 [00:00<00:00,  8.43it/s, v_num=23]    r2:  tensor(0.8939, grad_fn=<CloneBackward0>) tensor(0.8939, grad_fn=<MeanBackward0>)
# Epoch 118: 100%|██████████| 6/6 [00:00<00:00,  9.72it/s, v_num=23]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:47, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47     return trainer_fn(*args, **kwargs)
#      49 except _TunerExitException:
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:574, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     568 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     569     self.state.fn,
#     570     ckpt_path,
#     571     model_provided=True,
#     572     model_connected=self.lightning_module is not None,
#     573 )
# --> 574 self._run(model, ckpt_path=ckpt_path)
#     576 assert self.state.stopped
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:981, in Trainer._run(self, model, ckpt_path)
#     978 # ----------------------------
#     979 # RUN THE TRAINER
#     980 # ----------------------------
# --> 981 results = self._run_stage()
#     983 # ----------------------------
#     984 # POST-Training CLEAN UP
#     985 # ----------------------------
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:1025, in Trainer._run_stage(self)
#    1024 with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1025     self.fit_loop.run()
#    1026 return None
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py:205, in _FitLoop.run(self)
#     204 self.on_advance_start()
# --> 205 self.advance()
#     206 self.on_advance_end()
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py:363, in _FitLoop.advance(self)
#     362 assert self._data_fetcher is not None
# --> 363 self.epoch_loop.run(self._data_fetcher)
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/loops/training_epoch_loop.py:141, in _TrainingEpochLoop.run(self, data_fetcher)
#     140 self.advance(data_fetcher)
# --> 141 self.on_advance_end(data_fetcher)
#     142 self._restarting = False
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/loops/training_epoch_loop.py:295, in _TrainingEpochLoop.on_advance_end(self, data_fetcher)
#     293     call._call_lightning_module_hook(self.trainer, "on_validation_model_zero_grad")
# --> 295 self.val_loop.run()
#     296 self.trainer.training = True
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/loops/utilities.py:178, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     177 with context_manager():
# --> 178     return loop_run(self, *args, **kwargs)
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/loops/evaluation_loop.py:128, in _EvaluationLoop.run(self)
#     127     dataloader_iter = None
# --> 128     batch, batch_idx, dataloader_idx = next(data_fetcher)
#     129 if previous_dataloader_idx != dataloader_idx:
#     130     # the dataloader has changed, notify the logger connector
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/loops/fetchers.py:133, in _PrefetchDataFetcher.__next__(self)
#     131 elif not self.done:
#     132     # this will run only when no pre-fetching was done.
# --> 133     batch = super().__next__()
#     134 else:
#     135     # the iterator is empty
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/loops/fetchers.py:60, in _DataFetcher.__next__(self)
#      59 try:
# ---> 60     batch = next(self.iterator)
#      61 except StopIteration:
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/utilities/combined_loader.py:341, in CombinedLoader.__next__(self)
#     340 assert self._iterator is not None
# --> 341 out = next(self._iterator)
#     342 if isinstance(self._iterator, _Sequential):
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/utilities/combined_loader.py:142, in _Sequential.__next__(self)
#     141 try:
# --> 142     out = next(self.iterators[0])
#     143 except StopIteration:
#     144     # try the next iterator
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1328, in _MultiProcessingDataLoaderIter._next_data(self)
#    1327 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1328 idx, data = self._get_data()
#    1329 self._tasks_outstanding -= 1
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1294, in _MultiProcessingDataLoaderIter._get_data(self)
#    1293 while True:
# -> 1294     success, data = self._try_get_data()
#    1295     if success:
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1132, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1131 try:
# -> 1132     data = self._data_queue.get(timeout=timeout)
#    1133     return (True, data)
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     112 timeout = deadline - time.monotonic()
# --> 113 if not self._poll(timeout):
#     114     raise Empty
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/multiprocessing/connection.py:440, in Connection._poll(self, timeout)
#     439 def _poll(self, timeout):
# --> 440     r = wait([self], timeout)
#     441     return bool(r)
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/multiprocessing/connection.py:948, in wait(object_list, timeout)
#     947 while True:
# --> 948     ready = selector.select(timeout)
#     949     if ready:
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 trainer.fit(model, dm)
#       2 trainer.validate(model, dm)
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:538, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     536 self.state.status = TrainerStatus.RUNNING
#     537 self.training = True
# --> 538 call._call_and_handle_interrupt(
#     539     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     540 )
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:64, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      62     if isinstance(launcher, _SubprocessScriptLauncher):
#      63         launcher.kill(_get_sigkill_signal())
# ---> 64     exit(1)
#      66 except BaseException as exception:
#      67     _interrupt(trainer, exception)
#
# NameError: name 'exit' is not defined

# %%
dm.setup("fit")

# %%
for i, batch in enumerate(dm.train_dataloader()):
    print(batch, np.unique(batch.batch))
    _, mask_idx = apply_mask(batch)
