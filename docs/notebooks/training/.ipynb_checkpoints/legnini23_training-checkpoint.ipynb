# %%
from graph_transformer_long_range_niches.tl import pad_batch
from graph_transformer_long_range_niches._paths import CFG_FILES, RESULTS, FIG_PATH, LEGNINI23
from graph_transformer_long_range_niches.model import LitGNNTransformer, LitGNNTransformerMasked
from graph_transformer_long_range_niches.modules import LitGCNMasked, LitGCN
from graph_transformer_long_range_niches.pl import CustomColormap, plot_attention_sender_receiver, plot_attention_sender_receiver, SelfAttentionRelevance, calculate_attention, normalized_attention, normalized_class_attention
from graph_transformer_long_range_niches.pp import prepare_geome_dataset, split_adata
from graph_transformer_long_range_niches.config import load_config
from graph_transformer_long_range_niches.tl.geome_dataloader import GraphAnnDataModule

import warnings
warnings.filterwarnings("ignore")

from torch_geometric.loader import DataLoader

from pathlib import Path
import wandb
import torch
import os

## plotting
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import pickle

import scanpy as sc
import squidpy as sq

from sklearn.preprocessing import MinMaxScaler
# Out:
# /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/numba/core/decorators.py:246: RuntimeWarning: nopython is set for njit and is ignored
#   warnings.warn('nopython is set for njit and is ignored', RuntimeWarning)

# %%
def plot_history(history_callback, subset_term=None):
    history = pd.DataFrame(history_callback.history)
    if subset_term is not None:
        history = history[[c for c in history.columns if subset_term in c]]
    ax = history[[c for c in history.columns if 'train' in c]].plot()
    plt.gca().set_prop_cycle(None)
    history[[c for c in history.columns if 'val' in c]].plot(style='--', ax=ax)
    plt.grid(True)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

# %%
import math
from pytorch_lightning.callbacks import ModelCheckpoint, LearningRateMonitor, EarlyStopping, Callback, Timer
import pytorch_lightning as pl

class MetricsHistory(Callback):
    def __init__(self):
        super().__init__()
        self.history = []
        
    def on_train_epoch_end(self, trainer, pl_module):
        metrics = trainer.callback_metrics
        # Convert tensor values to float
        epoch_dict = {k: v.item() if hasattr(v, 'item') else v 
                     for k, v in metrics.items()}
        epoch_dict['epoch'] = trainer.current_epoch
        self.history.append(epoch_dict)

# %% [markdown]
# # InterScale training
#
#
# 0. Create `config.yaml` file
# 1. Load `cfg` and `adata` object
# 2. Prepare PyG data
# 3. Train GNN (Pre-training)
# 4. Train Transformer (Fine-tuning, global interactions)

# %%
FOLDER = "legnini23"
pre_trained_gcn = Path(RESULTS, 'legnini23', 'gcn_pretrained.ckpt')
cfg_path = "/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/Legnini_23/legnini23_genes_sample_gnn.yaml"

# %% [markdown]
# ### Load config and adata

# %%
cfg = load_config(cfg_path)

# %%
cfg.dataset.h5ad_data
# Out:
# '/lustre/groups/ml01/projects/2024_spatial_long_range_GT_francesca.drummer/data/legnini23.h5ad'

# %%
adata = sc.read_h5ad(cfg.dataset.h5ad_data)
adata
# Out:
# AnnData object with n_obs × n_vars = 43762 × 88
#     obs: 'Cell', 'Area', 'x', 'y', 'sample', 'condition', 'organoid', 'obs_names'
#     var: 'gene_ids', 'feature_types'
#     obsm: 'spatial'
#     layers: 'log1p_norm', 'norm_ftsqrt', 'raw'

# %%
print(adata.X[:10, :10])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 23 stored elements and shape (10, 10)>
#   Coords	Values
#   (0, 5)	5.166667461395264
#   (1, 0)	0.7994269132614136
#   (1, 1)	0.7994269132614136
#   (3, 0)	0.8773584961891174
#   (3, 1)	2.632075548171997
#   (3, 5)	0.8773584961891174
#   (4, 0)	0.5310913920402527
#   (4, 1)	0.5310913920402527
#   (4, 3)	0.17703045904636383
#   (5, 5)	3.3214285373687744
#   (6, 0)	1.9647890329360962
#   (6, 5)	2.619718551635742
#   (7, 0)	1.282168984413147
#   (7, 1)	2.3079042434692383
#   (7, 5)	0.25643378496170044
#   (8, 0)	1.7464789152145386
#   (8, 1)	0.8732394576072693
#   (8, 5)	0.43661972880363464
#   (9, 0)	0.7172237038612366
#   (9, 1)	1.4344474077224731
#   (9, 2)	0.7172237038612366
#   (9, 3)	0.7172237038612366
#   (9, 5)	0.7172237038612366

# %%
# clustering

# %%
train_size, val_size, test_size = float(cfg.dataset.train_size), float(cfg.dataset.val_size), float(cfg.dataset.test_size)
print(f'Train size: {train_size}, val size: {val_size} and test size: {test_size}')
# Out:
# Train size: 0.7, val size: 0.2 and test size: 0.1

# %%
split_adata(adata, split_obs=cfg.dataset.obs_split, val_size=val_size, test_size=test_size, seed = cfg.optim.seed, stratify_groups = cfg.dataset.prediction_obs)
# Out:
# Test size > 0
# {'counts': {'train': 23890, 'val': 13228, 'test': 6644}, 'groups': {'train': ['slide1_C2-1', 'slide1_C2-3', 'slide1_C2-5', 'slide4_A2-2', 'slide1_B2-3', 'slide1_A2-1', 'slide4_B2-3', 'slide4_A2-1', 'slide4_A2-3', 'slide1_A2-2', 'slide1_B2-2'], 'val': ['slide4_B2-2', 'slide1_C2-2', 'slide1_D2-3', 'slide1_D2-2'], 'test': ['slide4_B2-1', 'slide1_B2-1']}}
# AnnData object with n_obs × n_vars = 43762 × 88
#     obs: 'Cell', 'Area', 'x', 'y', 'sample', 'condition', 'organoid', 'obs_names', 'split'
#     var: 'gene_ids', 'feature_types'
#     obsm: 'spatial'
#     layers: 'log1p_norm', 'norm_ftsqrt', 'raw'

# %%
# cross-gene vs cross-cell evaluation
cfg.set_new_allowed(True)
cfg.defrost()
cfg.optim.cross_corr = 'gene'
cfg.optim.loss = 'GaussianNLL'
# cfg.dataset.batch_size = 3
# cfg.dataset.pct_mask_nodes = 0.3
# cfg.model.decoder.type = 'nonlinear'
cfg.freeze()

# %%
pyg_data_list, _ = prepare_geome_dataset(adata, cfg)
#pyg_data_list
# Out:
# coord_type: generic
# library_key: sample
# n_neighs: 6
# radius: 200
# call new
# call new
# call new
# call new

# %%
train_ds, val_ds, test_ds = pyg_data_list[0], pyg_data_list[1], pyg_data_list[2]

# %%
# set number of classes and number of features
cfg.dataset.merge_from_list(['num_features', len(train_ds[0].x[1])])
if 'classification' in cfg.dataset.prediction_task:
  cfg.dataset.merge_from_list(['num_classes', len(train_ds[0].y[1])])

# %%
dm = GraphAnnDataModule(datas=pyg_data_list, 
                           num_workers=1, 
                           batch_size=int(cfg.dataset.batch_size), 
                           pct_mask_nodes=cfg.dataset.pct_mask_nodes,
                           learning_type="node")
# Out:
# Masked dataloader

# %%
steps_per_epoch = math.ceil(len(train_ds) / cfg.dataset.batch_size)
print(steps_per_epoch)
early_stop_callback = EarlyStopping(monitor="val_r2", min_delta=0.05, patience=20*steps_per_epoch, verbose=False, mode="max")
lr_monitor = LearningRateMonitor(logging_interval='epoch')
timer = Timer()
history_callback = MetricsHistory()

# %%
model = LitGCNMasked(cfg)
#model = LitGNNTransformerMasked(cfg)
# Out:
# cross-gene per cellcorrelation metrics

# %%
trainer = pl.Trainer(min_epochs=1, 
                     max_epochs=100,
                     enable_progress_bar=False,
                     callbacks=[lr_monitor, early_stop_callback, timer, history_callback],
                     log_every_n_steps=steps_per_epoch,
                     # Sanity checks: Debugging model
                     #overfit_batches=1,
)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model, dm)
trainer.validate(model, dm)
# Out:
#   | Name   | Type            | Params | Mode
# --------------------------------------------------
# 0 | loss   | GaussianNLLLoss | 0      | eval
# 1 | layers | ModuleList      | 3.8 M  | eval
# 2 | out    | Linear          | 1.9 M  | eval
# --------------------------------------------------
# 5.7 M     Trainable params
# 0         Non-trainable params
# 5.7 M     Total params
# 22.715    Total estimated model params size (MB)
# 0         Modules in train mode
# 11        Modules in eval mode
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_mse          │    0.1424071490764618     │
# │     val_pearson_corr      │    0.5715016722679138     │
# │          val_r2           │    0.3027993142604828     │
# └───────────────────────────┴───────────────────────────┘
# [{'val_mse': 0.1424071490764618,
#   'val_r2': 0.3027993142604828,
#   'val_pearson_corr': 0.5715016722679138}]

# %%
#trainer.save_checkpoint(Path(RESULTS, 'legnini23', 'gcn_pretrained.ckpt'))

# %%
# After training, get the time metrics
total_time = timer.time_elapsed("train")  # total training time in seconds
avg_epoch_time = timer.time_elapsed("train") / trainer.current_epoch  # average time per epoch

print(f"Total training time: {total_time:.2f} seconds")
print(f"Average epoch time: {avg_epoch_time:.2f} seconds")
# Out:
# Total training time: 971.67 seconds
# Average epoch time: 17.99 seconds

# %%
plot_history(history_callback, subset_term='mse')
plot_history(history_callback, subset_term='r2')
#plot_history(history_callback, subset_term='pearson_corr')

# %% [markdown]
# ### Test dataloader

# %%
dm.setup("fit")

# %%
for i, batch in enumerate(dm.train_dataloader()):
    print(batch, np.unique(batch.batch))
# Out:
# DataBatch(x=[5292, 88], edge_index=[2, 59178], obs_names=[5292], mask=[5292], batch=[5292], ptr=[4]) [0 1 2]
# DataBatch(x=[6572, 88], edge_index=[2, 63220], obs_names=[6572], mask=[6572], batch=[6572], ptr=[4]) [0 1 2]
# DataBatch(x=[7360, 88], edge_index=[2, 71046], obs_names=[7360], mask=[7360], batch=[7360], ptr=[4]) [0 1 2]
# DataBatch(x=[4666, 88], edge_index=[2, 44660], obs_names=[4666], mask=[4666], batch=[4666], ptr=[3]) [0 1]

# %% [markdown]
# ## Model evaluation

# %%
# samples in test set 
adata[adata.obs['split'] == 'test'].obs.groupby(['split', 'sample', 'condition']).size()
# Out:
# split  sample       condition
# test   slide1_B2-1  SHH          3299
#        slide4_B2-1  SHH          3345
# dtype: int64

# %%
dm.setup('test')

# %% [markdown]
# ### GNNTransformer

# %%
for i, batch in enumerate(dm.test_dataloader()):
    print(batch)
    padded_h_node, transformer_out, src_padding_mask, index_nodes, dec_out = model.evaluation(batch)
# Out:
# DataBatch(x=[6644, 88], edge_index=[2, 63920], obs_names=[6644], mask=[6644], batch=[6644], ptr=[3])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 3
#       1 for i, batch in enumerate(dm.test_dataloader()):
#       2     print(batch)
# ----> 3     padded_h_node, transformer_out, src_padding_mask, index_nodes, dec_out = model.evaluation(batch)
#
# ValueError: not enough values to unpack (expected 5, got 2)

# %%
print(transformer_out.shape, dec_out.shape)

# %%
transformer_out_list, dec_out_list = [], []
for batch_idx in np.unique(batch.batch):
    transformer_out_list.append(transformer_out[(batch.batch == batch_idx)])
    dec_out_list.append(dec_put[batch.batch == batch_idx])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 3
#       1 transformer_out_list, dec_out_list = [], []
#       2 for batch_idx in np.unique(batch.batch):
# ----> 3     transformer_out_list.append(transformer_out[(batch.batch == batch_idx)])
#       4     dec_out_list.append(dec_put[batch.batch == batch_idx])
#
# NameError: name 'transformer_out' is not defined

# %% [markdown]
# ### GCN

# %%
gcn_model = LitGCNMasked.load_from_checkpoint(pre_trained_gcn)
# Out:
# cross-gene per cellcorrelation metrics

# %%
dm.setup('test')

# %%
for i, batch in enumerate(dm.test_dataloader()):
    print(batch)
    z, x = gcn_model.evaluation(batch)
# Out:
# DataBatch(x=[6644, 88], edge_index=[2, 63920], obs_names=[6644], mask=[6644], batch=[6644], ptr=[3])

# %%
print(x.shape, z.shape)
# Out:
# torch.Size([6644, 88]) torch.Size([6644, 16])

# %%
x_list, z_list = [], []
for batch_idx in np.unique(batch.batch):
    x_list.append(x[batch.batch == batch_idx])
    z_list.append(z[batch.batch == batch_idx])

# %%
print(x_list[0].shape, z_list[1].shape)
# Out:
# torch.Size([3299, 88]) torch.Size([3345, 16])

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

def predict_gene_r2(adata, layers_pred):
    # Convert y_true to a dense array
    y_true = sub_adata.X.toarray()  # Convert sparse matrix to dense NumPy array
    
    # Convert predictions to NumPy arrays
    y_pred = sub_adata.layers[layers_pred]
    
    # Ensure predictions are also NumPy arrays (if they're tensors)
    if not isinstance(y_pred, np.ndarray):
        y_pred = np.array(y_pred)
    
    # Compute R² scores for each gene
    r2_scores = [r2_score(y_true[:, i], y_pred[:, i]) for i in range(y_true.shape[1])]
    
    # Convert to DataFrame for easy sorting
    genes = sub_adata.var_names  # Gene names
    r2_df = pd.DataFrame({'gene': genes, 'r2': r2_scores})
    
    # Get top 5 genes for each model
    top = r2_df.nlargest(5, 'r2')
    
    print("Top 5 genes for GNN model:\n", top)

# %%
sample = 'slide4_B2-1'
idx = 1

sub_adata = adata[adata.obs['sample']==sample]
print(sub_adata)
sub_adata.layers['gnn_z'] = x_list[idx].detach().numpy()
predict_gene_r2(sub_adata, 'gnn_z')
sq.pl.spatial_scatter(
    sub_adata,
    color = ['SHH', 'PAX6', 'DBX1'],
    layer = 'norm_ftsqrt',
    cmap = 'viridis',
    shape= None
)
sq.pl.spatial_scatter(
    sub_adata,
    color = ['SHH', 'PAX6', 'DBX1'],
    layer = 'gnn_z',
    cmap = 'viridis',
    shape= None
)
# Out:
# View of AnnData object with n_obs × n_vars = 3345 × 88
#     obs: 'Cell', 'Area', 'x', 'y', 'sample', 'condition', 'organoid', 'obs_names', 'split'
#     var: 'gene_ids', 'feature_types'
#     obsm: 'spatial'
#     layers: 'log1p_norm', 'norm_ftsqrt', 'raw'
# Top 5 genes for GNN model:
#        gene        r2
# 70   PTCH1  0.584204
# 55  NKX6.1  0.561848
# 69   PROM1  0.527527
# 32    GLI3  0.510122
# 31    GLI2  0.497208
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`

# %%
sample = 'slide1_B2-1'
idx = 0

sub_adata = adata[adata.obs['sample']==sample]
print(sub_adata)
sub_adata.layers['gnn_z'] = x_list[idx].detach().numpy()
predict_gene_r2(sub_adata, 'gnn_z')
sq.pl.spatial_scatter(
    sub_adata,
    color = ['SHH', 'PAX6', 'DBX1'],
    layer = 'norm_ftsqrt',
    cmap = 'viridis',
    shape= None
)
sq.pl.spatial_scatter(
    sub_adata,
    color = ['SHH', 'PAX6', 'DBX1'],
    layer = 'gnn_z',
    cmap = 'viridis',
    shape= None
)
# Out:
# View of AnnData object with n_obs × n_vars = 3299 × 88
#     obs: 'Cell', 'Area', 'x', 'y', 'sample', 'condition', 'organoid', 'obs_names', 'split'
#     var: 'gene_ids', 'feature_types'
#     obsm: 'spatial'
#     layers: 'log1p_norm', 'norm_ftsqrt', 'raw'
# Top 5 genes for GNN model:
#           gene        r2
# 78      STMN2  0.478329
# 64       PAX6  0.299783
# 55     NKX6.1  0.212982
# 13  Circ.CDR1  0.184371
# 46       MAP2  0.136649
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`

# %%
def evaluate_embedding_space(adata, X, model):
    W = gcn_model.out.weight
    emb = torch.matmul(X, W) # [N, E]

    for i in range(emb.shape[1]):
        adata.obs[f'emb_{i}'] = emb[:, i].detach().numpy()

    emb_np = emb.detach().numpy()
    adata_emb = anndata.AnnData(emb_np)
    adata_emb.var_names = [f"Embedding_{i}" for i in range(emb_np.shape[1])]  # Label embeddings
    adata_emb.obs['cell_type'] = ['None']*emb_np.shape[0]
    
    sc.pl.heatmap(adata_emb, var_names=adata_emb.var_names, groupby='cell_type')

# %%
W = gcn_model.out.weight

# %%
print(W.shape, torch.transpose(W, 0, 1).shape, z_list[0].shape)
# Out:
# torch.Size([88, 16]) torch.Size([16, 88]) torch.Size([3299, 88])

# %%
emb = torch.matmul(x_list[0], W) # [N, E]
emb.shape
# Out:
# torch.Size([3299, 16])

# %%
emb[:, 0]
# Out:
# tensor([61.9212, 52.9619, 53.0452,  ..., 56.7107, 51.4809, 46.9600],
#        grad_fn=<SelectBackward0>)

# %%
for i in range(emb.shape[1]):
    sub_adata.obs[f'emb_{i}'] = emb[:, i].detach().numpy()

# %%
sq.pl.spatial_scatter(
    sub_adata,
    color = ['emb_1', 'emb_2', 'emb_3', 'emb_4', 'emb_5', 'emb_6', 'emb_7', 'emb_8', 'emb_9', 'emb_10', 'emb_11', 'emb_12'],
    layer = 'gnn_z',
    cmap = 'viridis',
    shape= None
)
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3299 × 16

# %%
adata.var_names
# Out:
# Index(['Embedding_0', 'Embedding_1', 'Embedding_2', 'Embedding_3',
#        'Embedding_4', 'Embedding_5', 'Embedding_6', 'Embedding_7',
#        'Embedding_8', 'Embedding_9', 'Embedding_10', 'Embedding_11',
#        'Embedding_12', 'Embedding_13', 'Embedding_14', 'Embedding_15'],
#       dtype='object')

# %%
import scanpy as sc
import anndata
import pandas as pd

emb_np = emb.detach().numpy()
adata = anndata.AnnData(emb_np)
adata.var_names = [f"Embedding_{i}" for i in range(emb_np.shape[1])]  # Label embeddings
adata.obs['cell_type'] = ['None']*emb_np.shape[0]

sc.pl.heatmap(adata, var_names=adata.var_names, groupby='cell_type')

# %% [markdown]
# ### Linear Decoder disentanglement

# %%
gcn_model.out.weight.shape
# Out:
# torch.Size([88, 16])

# %%
# Prepare dataframe with values and niches or cell types
def make_dataframe(data, obs_names, index_nodes, adata, label):
    sub_obs_names = obs_names[index_nodes[0]]
    str_list = [str(i.astype(int)) for i in sub_obs_names.numpy()]
    sub_adata = adata[adata.obs_names.isin(str_list)].copy()
    df = pd.DataFrame(data, index=cm.get_category_colors()[sub_adata.obs[label]])
    return df

df = make_dataframe(diff, pyg_datas[0].obs_names, index_nodes, adata, 'niche')

# %% [markdown]
# ## GNNTransformer (from pretrained GNN)

# %%
gcn_model = LitGCNMasked.load_from_checkpoint(pre_trained_gcn)
# Out:
# cross-gene per cellcorrelation metrics

# %%
model_gnntrans = LitGNNTransformerMasked(cfg, pretrained_gnn_path = pre_trained_gcn)
# Out:
# cross-gene per cellcorrelation metrics
# cross-gene correlation metrics
# cross-gene per cellcorrelation metrics
# Loaded pre-trained GNN from: /lustre/groups/ml01/projects/2024_spatial_long_range_GT_francesca.drummer/results/legnini23/gcn_pretrained.ckpt
# GNN parameters have been frozen

# %%
trainer = pl.Trainer(min_epochs=1, 
                     max_epochs=1000,
                     enable_progress_bar=False,
                     callbacks=[lr_monitor, early_stop_callback, timer, history_callback],
                     log_every_n_steps=steps_per_epoch,
                     # Sanity checks: Debugging model
                     #overfit_batches=1,
)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model_gnntrans, dm)
trainer.validate(model_gnntrans, dm)
# Out:
#   | Name                   | Type                       | Params | Mode
# ------------------------------------------------------------------------------
# 0 | loss                   | GaussianNLLLoss            | 0      | train
# 1 | graph_pred_linear_list | ModuleList                 | 0      | train
# 2 | graph_pred_linear      | Sequential                 | 49.4 K | train
# 3 | norm_input             | LayerNorm                  | 32     | train
# 4 | gnn                    | LitGCNMasked               | 28.4 K | train
# 5 | transformer_encoder    | TransformerNodeEncoderHook | 19.3 K | train
#   | other params           | n/a                        | 16     | n/a
# ------------------------------------------------------------------------------
# 68.7 K    Trainable params
# 28.4 K    Non-trainable params
# 97.1 K    Total params
# 0.388     Total estimated model params size (MB)
# 52        Modules in train mode
# 0         Modules in eval mode
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val_mse          │    3.1300008296966553     │
# │     val_pearson_corr      │    0.8027553558349609     │
# │          val_r2           │      0.5922891497612      │
# └───────────────────────────┴───────────────────────────┘
# [{'val_mse': 3.1300008296966553,
#   'val_r2': 0.5922891497612,
#   'val_pearson_corr': 0.8027553558349609}]

# %%
gnntrans_pretrained = Path(RESULTS, 'legnini23', 'gcnTrans_pretrained.ckpt')

# %%
trainer.save_checkpoint(Path(RESULTS, 'legnini23', 'gcnTrans_pretrained.ckpt'))

# %%
plot_history(history_callback, subset_term='mse')
plot_history(history_callback, subset_term='r2')
#plot_history(history_callback, subset_term='pearson_corr')

# %%
model_gnntrans = LitGNNTransformerMasked.load_from_checkpoint(gnntrans_pretrained)
# Out:
# cross-gene per cellcorrelation metrics
# cross-gene correlation metrics

# %%
dm.setup('test')

# %%
for i, batch in enumerate(dm.val_dataloader()):
    print(batch)
    for batch_idx in np.unique(batch.batch):
        transformer_in, transformer_out, src_padding_mask, index_nodes, dec_out = model_gnntrans.evaluation(batch)
        print(batch.obs_names[batch.batch == batch_idx])
        batch_obs_names_str = batch.obs_names[batch.batch == batch_idx].numpy().astype(int).astype(str)[index_nodes[batch_idx]]
        sub_adata = adata[adata.obs_names.isin(batch_obs_names_str)]
        sub_adata.layers['y_rec'] = dec_out[2000*batch_idx:2000*(batch_idx+1)].detach().numpy()
        sq.pl.spatial_scatter(
            sub_adata,
            color = ['SHH', 'PAX6', 'DBX1'],
            layer = 'norm_ftsqrt',
            cmap = 'viridis_r',
            shape= None
        )
        sq.pl.spatial_scatter(
            sub_adata,
            color = ['SHH', 'PAX6', 'DBX1'],
            layer = 'y_rec',
            cmap = 'viridis_r',
            shape= None
        )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 for i, batch in enumerate(dm.val_dataloader()):
#       2     print(batch)
#       3     for batch_idx in np.unique(batch.batch):
#
# File /ictstr01/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/graph_transformer_long_range_niches/tl/geome_dataloader.py:127, in GraphAnnDataModule.val_dataloader(self)
#     125 def val_dataloader(self):
#     126     """Returns the validation dataloader."""
# --> 127     return self._get_dataloader(self._val_dataloader)
#
# AttributeError: 'GraphAnnDataModule' object has no attribute '_val_dataloader'

# %%
def evaluate_embedding_space(adata, Z, W):
    """
    Z: latent space input [N, E]
    W: weight matrix from decoder [F, E]
    """
    emb = torch.matmul(X, W) # [N, E]

    for i in range(emb.shape[1]):
        adata.obs[f'emb_{i}'] = emb[:, i].detach().numpy()

    emb_np = emb.detach().numpy()
    adata_emb = anndata.AnnData(emb_np)
    adata_emb.var_names = [f"Embedding_{i}" for i in range(emb_np.shape[1])]  # Label embeddings
    adata_emb.obs['cell_type'] = ['None']*emb_np.shape[0]
    
    sc.pl.heatmap(adata_emb, var_names=adata_emb.var_names, groupby='cell_type')

# %%
model_gnntrans
# Out:
# LitGNNTransformerMasked(
#   (loss): GaussianNLLLoss()
#   (graph_pred_linear_list): ModuleList()
#   (graph_pred_linear): Sequential(
#     (0): Sequential(
#       (0): Linear(in_features=16, out_features=256, bias=True)
#       (1): BatchNorm1d(256, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (1): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#     )
#     (2): Linear(in_features=128, out_features=88, bias=True)
#   )
#   (norm_input): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#   (gnn): LitGCN(
#     (loss): GaussianNLLLoss()
#     (mse): MeanSquaredError()
#     (r2_raw): R2Score()
#     (r2): R2Score()
#     (r2_single): R2Score()
#     (layers): ModuleList(
#       (0): GCNConv(88, 256)
#       (1): ReLU(inplace=True)
#       (2): Dropout(p=0.1, inplace=False)
#       (3): GCNConv(256, 16)
#     )
#     (out): Linear(in_features=16, out_features=88, bias=True)
#   )
#   (transformer_encoder): TransformerNodeEncoderHook(
#     (transformer_encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-1): 2 x CustomTransformerEncoderLayer(
#           (self_attn): MultiHeadAttentionWithEdits(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=16, out_features=16, bias=True)
#           )
#           (linear1): Linear(in_features=16, out_features=256, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (linear2): Linear(in_features=256, out_features=16, bias=True)
#           (norm1): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (norm2): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (dropout2): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#     )
#     (norm_input): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#   )
# )

# %%
for i, batch in enumerate(dm.test_dataloader()):
    print(batch)
    x, z_gnn = gcn_model.evaluation(batch)
    transformer_in, transformer_out, src_padding_mask, index_nodes, dec_out = model_gnntrans.evaluation(batch)
    print(z.shape, dec_out.shape)
    for batch_idx in np.unique(batch.batch):
        batch_obs_names_str = batch.obs_names[batch.batch == batch_idx].numpy().astype(int).astype(str)[index_nodes[batch_idx]]
        print(len(batch_obs_names_str))
        idx_nodes = np.where(adata.obs_names.isin(batch_obs_names_str))
        print(idx_nodes)
        nr_cells = len(batch_obs_names_str)
        sub_adata = adata[adata.obs_names.isin(batch_obs_names_str)]
        Z = dec_out[nr_cells*batch_idx:nr_cells*(batch_idx+1)].detach().numpy()
        sub_adata.layers['y_pred_gnntrans'] = dec_out[nr_cells*batch_idx:nr_cells*(batch_idx+1)].detach().numpy()
        #sub_adata.layers['y_pred_gnn'] = z_gnn[nr_cells*batch_idx:nr_cells*(batch_idx+1)].detach().numpy()
        predict_gene_r2(adata, 'y_pred_gnntrans')
        evaluate_embedding_space(sub_adata, torch.tensor(Z), model_gnntrans)
# Out:
# DataBatch(x=[6644, 88], edge_index=[2, 63920], obs_names=[6644], mask=[6644], batch=[6644], ptr=[3])
# torch.Size([6644, 16]) torch.Size([4000, 88])
# 2000
# (array([4717, 4720, 4723, ..., 8013, 8014, 8015]),)
# Top 5 genes for GNN model:
#       gene        r2
# 32   GLI3  0.246572
# 39   IRX3  0.222415
# 69  PROM1  0.187383
# 31   GLI2  0.107039
# 15   CUL3  0.078258
# 2000
# (array([36995, 36998, 36999, ..., 40337, 40338, 40339]),)
# Top 5 genes for GNN model:
#       gene        r2
# 69  PROM1  0.162251
# 31   GLI2  0.112509
# 32   GLI3  0.086102
# 41    JUN  0.062008
# 29   GAD1  0.050382

# %%
sub_adata
# Out:
# AnnData object with n_obs × n_vars = 2000 × 88
#     obs: 'Cell', 'Area', 'x', 'y', 'sample', 'condition', 'organoid', 'obs_names', 'split'
#     var: 'gene_ids', 'feature_types'
#     obsm: 'spatial'
#     layers: 'log1p_norm', 'norm_ftsqrt', 'raw', 'y_pred_gnntrans'

# %%
sq.pl.spatial_scatter(
            sub_adata,
            color = ['PTPRZ1', 'GLI3', 'PAX6', 'DBX2'],
            layer = 'log1p_norm',
            cmap = 'viridis',
            shape= None
        )
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
