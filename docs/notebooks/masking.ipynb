# %%
from pathlib import Path
import wandb
import torch
import os

# %%
parameter_dict = {}
parameter_dict.update({
                # GNN configs
                'gnn.num_layers': {'values': [2,4]},
                'gnn.hidden_dim': {'values': [32, 64, 128, 256, 512]},
                'gnn.embed_dim': {'values': [16, 32, 64, 128, 256, 512]},  # List all possible values
            })

sweep_config = {
            'method': 'random',  # Can be 'grid', 'random', or 'bayes'
            'metric': {
                'name': 'val_r2', 
                'goal': 'maximize'},  # Use 'val_r2' for regression tasks
        }
sweep_config['parameters'] = parameter_dict

# %%
sweep_id = wandb.sweep(sweep_config, project='InterScale_hyperparameter_sweep')
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Create sweep with ID: v719z4dc
# Sweep URL: https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/sweeps/v719z4dc

# %%
def main_sweep(cfg_path, sweep_goal):
    sweep_run = wandb.init(project='InterScale_hyperparameter_sweep', 
                 job_type = 'model_training')
    sweep_config = wandb.config
    print(sweep_config)

# %%
def train_sweep_function():
    # Pass the sweep run object to main
    main_sweep('cfg', 'sweep_goal')

# Run the sweep agent
wandb.agent(sweep_id, function=train_sweep_function)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Agent Starting Run: fz3u12gp with config:
# wandb: 	gnn.embed_dim: 32
# wandb: 	gnn.hidden_dim: 32
# wandb: 	gnn.num_layers: 2
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: francesca-drummer. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/ictstr01/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/docs/notebooks/wandb/run-20250227_182608-fz3u12gp</code>
# Syncing run <strong><a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/runs/fz3u12gp' target="_blank">icy-sweep-12</a></strong> to <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/sweeps/v719z4dc' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/sweeps/v719z4dc</a>
#  View project at <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep</a>
#  View sweep at <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/sweeps/v719z4dc' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/sweeps/v719z4dc</a>
#  View run at <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/runs/fz3u12gp' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/runs/fz3u12gp</a>
# {'gnn.embed_dim': 32, 'gnn.hidden_dim': 32, 'gnn.num_layers': 2}
#  View run <strong style="color:#cdcd00">icy-sweep-12</strong> at: <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/runs/fz3u12gp' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/runs/fz3u12gp</a><br/> View project at: <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250227_182608-fz3u12gp/logs</code>
# wandb: Agent Starting Run: hschwihy with config:
# wandb: 	gnn.embed_dim: 64
# wandb: 	gnn.hidden_dim: 128
# wandb: 	gnn.num_layers: 2
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/ictstr01/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/docs/notebooks/wandb/run-20250227_182621-hschwihy</code>
# Syncing run <strong><a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/runs/hschwihy' target="_blank">fearless-sweep-13</a></strong> to <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/sweeps/v719z4dc' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/sweeps/v719z4dc</a>
#  View project at <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep</a>
#  View sweep at <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/sweeps/v719z4dc' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/sweeps/v719z4dc</a>
#  View run at <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/runs/hschwihy' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/runs/hschwihy</a>
# {'gnn.embed_dim': 64, 'gnn.hidden_dim': 128, 'gnn.num_layers': 2}
#  View run <strong style="color:#cdcd00">fearless-sweep-13</strong> at: <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/runs/hschwihy' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep/runs/hschwihy</a><br/> View project at: <a href='https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep' target="_blank">https://wandb.ai/francesca-drummer/InterScale_hyperparameter_sweep</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250227_182621-hschwihy/logs</code>
# wandb: Ctrl + C detected. Stopping sweep.

# %%
print('Wandb initialize...')
sweep_run = wandb.init(project=cfg.wandb.project_name, 
                 config=cfg, 
                 name=run_name, 
                 job_type = 'model_training')
sweep_config = wandb.config
