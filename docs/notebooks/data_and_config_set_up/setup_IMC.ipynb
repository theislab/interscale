# %% [markdown]
# # Setup and download - IMC Type 1 Diabetes Pancreas data
#
# This tutorials shows how to set up an multiple slide spatial proteomics (IMC) dataset used from [Damond et al., 2019](https://doi.org/10.1016/j.cmet.2018.11.014). To follow along with this and the following tutorials, please execute the following steps first:
#
# - Set up InterScale environment (see instructions in ReadMe)
# - Download the sample data from the original publication from [Zenodo](https://zenodo.org/records/13907274)

# %%
import scanpy as sc
import squidpy as sq
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.sparse import issparse
import seaborn as sns

from pathlib import Path

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pathlib import Path

# set INTERSCALE_DIR to the current working directory
INTERSCALE_DIR = Path.cwd()
print(INTERSCALE_DIR)
# Out:
# /workspace

# %% [markdown]
# <mark>TODO: Change data path</mark>

# %%
IMC_PANCREAS = '/dss/dssfs03/tumdss/pn36po/pn36po-dss-0002/di93tig/Projects/A3_InterScale/data/spatial_proteomics_pancreas_t1d_IMC.h5ad'

# %% [markdown]
# ## Load data

# %%
adata_pancreas = sc.read_h5ad(IMC_PANCREAS)
adata_pancreas
# Out:
# AnnData object with n_obs × n_vars = 1776974 × 38
#     obs: 'ImageNumber', 'ObjectNumber', 'Location_Center_X', 'Location_Center_Y', 'Number_Object_Number', 'image_name', 'id', 'CellCat', 'CellType', 'case', 'slide', 'part', 'group', 'stage', 'duration', 'Aab status', 'Age', 'Gender', 'Ethnicity', 'BMI'
#     uns: 'morphology', 'neighbors', 'parent_structure'
#     obsm: 'spatial'
#     layers: 'MeanIntensity', 'MedianIntensity'

# %% [markdown]
# ## 1. Normalization
#
# The data needs to be normalized for InterScale. Check if the data is already normalized:

# %%
print(f'Min count: {adata_pancreas.X.min()}, Max count: {adata_pancreas.X.max()}')
# Out:
# Min count: 0.0, Max count: 98518.4583556652

# %%
for layer_name in ['MeanIntensity', 'MedianIntensity']:
    print(f'Min count: {adata_pancreas.layers[layer_name].min()}, Max count: {adata_pancreas.layers[layer_name].max()}')
# Out:
# Min count: 0.0, Max count: 2526.1143168119283
# Min count: 0.0, Max count: 1220.530029296875

# %% [markdown]
# The data is not yet normalized, so normalize like described in the publication: "raw IMC counts were 99th-percentile-normalized and scaled from 0 to 1 (scaled counts)."

# %%
percentile_99 = np.percentile(adata_pancreas.X, 99, axis=0)
pct_norm_99 = adata_pancreas.X / percentile_99
adata_pancreas.layers["pct-norm-99"] = np.clip(pct_norm_99, 0, 1)

# %%
print(f'Min count: {adata_pancreas.layers["pct-norm-99"].min()}, Max count: {adata_pancreas.layers["pct-norm-99"].max()}')
# Out:
# Min count: 0.0, Max count: 1.0

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
p1 = sns.histplot(adata_pancreas.X.sum(1), bins=100, kde=False, ax=axes[0])
axes[0].set_title("Total counts")
p2 = sns.histplot(adata_pancreas.layers["pct-norm-99"].sum(1), bins=100, kde=False, ax=axes[1])
axes[1].set_title("Norm to target sum 1")
plt.show()

# %% [markdown]
# ## 2. Calculate spatial connectivity matrix
#
# Use [`squidpy.gr.spatial_neighbors()`](https://squidpy.readthedocs.io/en/stable/api/squidpy.gr.spatial_neighbors.html)) to calculate the spatial connectivity. For image-based ST it is important to set `coord_type='generic'`. In Squidpy, you have the option between k-nearest neighbors, delaunay and radius based neighborhood. For InterScale, we use a `radius`-based neighborhood to capture density information. Find the radius for which the number of connected neighbors is approximately 10-30, depending on tissue density.

# %%
print('Nr. of images', len(np.unique(adata_pancreas.obs['ImageNumber'])))
# Out:
# Nr. of images 845

# %%
adata_pancreas.obs['ImageNumber'] = pd.Categorical(adata_pancreas.obs['ImageNumber'])

# %%
sq.gr.spatial_neighbors(
    adata_pancreas,
    coord_type = "generic",
    library_key = "ImageNumber",
    radius = 30,
)

# %%
# Calculate nr. of neighbors per cells
conn = adata_pancreas.obsp['spatial_connectivities']
# Print average number of connections per node
avg_connections = conn.nnz / conn.shape[0]  # total connections / number of nodes
print(f"Average number of connections per node: {avg_connections:.2f}")
# Out:
# Average number of connections per node: 25.22

# %%
sq.pl.spatial_scatter(
            adata_pancreas,
            color = ['CellCat','CellType'],
            spatial_key = 'spatial',
            library_key='image_name',
            library_id=['M25'],
            shape= None,
            size=50
)
# Out:
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(

# %%
sq.pl.spatial_scatter(
            adata_pancreas,
            color = ['CellCat','CellType'],
            spatial_key = 'spatial',
            library_key='image_name',
            library_id=['M25'],
            shape= None,
            connectivity_key="spatial_connectivities",
            size=50
)
# Out:
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(

# %% [markdown]
# ## 3. Optional: Calculate sliding windows
#
# Sliding windows are necessary in case the tissue slide contains more than 4k cells. First, check how many cells are at minimum or maximum in your dataset.

# %%
tissue_cell_number = adata_pancreas.obs.groupby('ImageNumber').size()
print(f"Nr cells per sliding window: Min: {tissue_cell_number.min()}, Max: {tissue_cell_number.max()}, Avg: {tissue_cell_number.mean()}")
# Out:
# Nr cells per sliding window: Min: 521, Max: 9396, Avg: 2102.9278106508877
# /tmp/ipykernel_1088497/3524064332.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_cell_number = adata_pancreas.obs.groupby('ImageNumber').size()

# %% [markdown]
# Select images that have more than some MAX number of cells.

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot histogram
ax.hist(tissue_cell_number, bins=50, edgecolor='black', alpha=0.7)

# Labels and title
ax.set_xlabel('Number of cells per window', fontsize=12)
ax.set_ylabel('Number of windows', fontsize=12)
ax.set_title('Distribution of cells per Image', fontsize=14, fontweight='bold')

# Add grid for better readability
ax.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# %%
MAX_NR_CELLS = 8000
MIN_NR_CELLS = 800
tissue_cell_number = adata_pancreas.obs.groupby('ImageNumber').size()
print(f'Images with less than {MIN_NR_CELLS} cells:', tissue_cell_number[tissue_cell_number < MIN_NR_CELLS])
print(f'Images with more than {MAX_NR_CELLS} cells:', tissue_cell_number[tissue_cell_number > MAX_NR_CELLS])
# Out:
# Images with less than 800 cells: ImageNumber
# 96     723
# 131    754
# 136    755
# 189    706
# 229    781
# 261    796
# 264    771
# 272    618
# 273    766
# 274    764
# 352    749
# 385    777
# 524    521
# 525    605
# 527    661
# 528    681
# 542    680
# 549    695
# 559    734
# 565    686
# 612    643
# 635    766
# 669    781
# 757    667
# dtype: int64
# Images with more than 8000 cells: ImageNumber
# 177    8662
# 408    9396
# 787    8590
# dtype: int64
# /tmp/ipykernel_1088497/3251425770.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_cell_number = adata_pancreas.obs.groupby('ImageNumber').size()

# %%
sq.pl.spatial_scatter(
    adata_pancreas[adata_pancreas.obs['ImageNumber'].isin([177, 408, 787])],
    spatial_key = 'spatial',
    library_key='ImageNumber', 
    #library_id = [839, 6],
    color="CellType", #cell_type_coarse",
    shape= None,
    size = 10,
)
# Out:
# /dss/dsshome1/05/di93tig/.local/lib/python3.10/site-packages/scanpy/plotting/_utils.py:432: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[value_to_plot + '_colors'] = colors_list
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(

# %%
# calculate sizes of images
adata_pancreas.obs['Location_Center_X']
# Out:
# 0           52.500000
# 1          128.000000
# 2          135.285714
# 3          449.526316
# 4          458.366667
#               ...
# 1776969    299.032787
# 1776970    284.336957
# 1776971    134.000000
# 1776972    157.400000
# 1776973    374.750000
# Name: Location_Center_X, Length: 1776974, dtype: float64

# %%
MAX_CELLS = 2500
tissue_cell_number = adata_pancreas.obs.groupby('ImageNumber').size()
batches_high_nr_cells = tissue_cell_number[tissue_cell_number > MAX_CELLS]
print(batches_high_nr_cells)
# Out:
# ImageNumber
# 1      4650
# 4      7147
# 5      3391
# 6      2518
# 7      3155
#        ...
# 837    2549
# 839    2836
# 840    3596
# 843    2980
# 844    3633
# Length: 242, dtype: int64
# /tmp/ipykernel_1088497/1254649840.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tissue_cell_number = adata_pancreas.obs.groupby('ImageNumber').size()

# %% [markdown]
# We observe that there are a slides with only a few cells but 2 slides with more than 4k cells. For this case we have the option to 1) increase the context length to max = 4875 or 2) calculate sliding windows for all slides that have more than 3k cells.

# %%
# Use the index of batches_high_nr_cells to get the image numbers
sub_adata = adata_pancreas[adata_pancreas.obs['ImageNumber'].isin(batches_high_nr_cells.index)]
sub_adata
# Out:
# View of AnnData object with n_obs × n_vars = 893704 × 38
#     obs: 'ImageNumber', 'ObjectNumber', 'Location_Center_X', 'Location_Center_Y', 'Number_Object_Number', 'image_name', 'id', 'CellCat', 'CellType', 'case', 'slide', 'part', 'group', 'stage', 'duration', 'Aab status', 'Age', 'Gender', 'Ethnicity', 'BMI'
#     uns: 'morphology', 'neighbors', 'parent_structure', 'spatial_neighbors'
#     obsm: 'spatial'
#     layers: 'MeanIntensity', 'MedianIntensity', 'pct-norm-99'
#     obsp: 'spatial_connectivities', 'spatial_distances'

# %%
print(f"Nr cells per for large images: Min: {batches_high_nr_cells.min()}, Max: {batches_high_nr_cells.max()}, Avg: {batches_high_nr_cells.mean()}")
# Out:
# Nr cells per for large images: Min: 2502, Max: 9396, Avg: 3692.99173553719

# %%
sq.tl.sliding_window(
    adata=sub_adata,
    library_key="ImageNumber",  # to stratify by sample
    window_size=600,
    overlap=0,
    copy=False,  # we modify in place
)
# Out:
# /usr/local/lib/python3.10/dist-packages/squidpy/gr/_utils.py:203: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   obj[key] = data

# %%
window_size = sub_adata.obs.groupby('sliding_window_assignment').size()
print(f"Nr cells per sliding window: Min: {window_size.min()}, Max: {window_size.max()}, Avg: {window_size.mean()}")
# Out:
# Nr cells per sliding window: Min: 2, Max: 4606, Avg: 1616.1012658227849
# /tmp/ipykernel_1088497/1767285025.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   window_size = sub_adata.obs.groupby('sliding_window_assignment').size()

# %%
sub_adata.obs["ImageNumber"]
# Out:
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
#           ...
# 1775785    844
# 1775786    844
# 1775787    844
# 1775788    844
# 1775789    844
# Name: ImageNumber, Length: 893704, dtype: category
# Categories (242, int64): [1, 4, 5, 6, ..., 839, 840, 843, 844]

# %% [markdown]
# With the sliding windows the maximum number of cells per sliding window is `2418`.
#
# <mark>TODO: Adjust max_seq_len in config file!</mark>
# Given this we adjust the `max_seq_len` from the model.global_component to `2418`. The default is `2000`.

# %%
del sub_adata.uns['sliding_window_assignment_colors']

# %%
sq.pl.spatial_scatter(
    sub_adata[sub_adata.obs['ImageNumber'].isin([839, 6])],
    spatial_key = 'spatial',
    library_key='ImageNumber', 
    #library_id = [839, 6],
    color="sliding_window_assignment", #cell_type_coarse",
    shape= None,
    size = 10,
)
# Out:
# /dss/dsshome1/05/di93tig/.local/lib/python3.10/site-packages/scanpy/plotting/_utils.py:432: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[value_to_plot + '_colors'] = colors_list
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(

# %%
sq.pl.spatial_scatter(
    sub_adata[sub_adata.obs['ImageNumber'].isin([177, 408, 787])],
    spatial_key = 'spatial',
    library_key='ImageNumber', 
    #library_id = [839, 6],
    color="sliding_window_assignment", #cell_type_coarse",
    shape= None,
    size = 10,
)
# Out:
# /dss/dsshome1/05/di93tig/.local/lib/python3.10/site-packages/scanpy/plotting/_utils.py:432: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[value_to_plot + '_colors'] = colors_list
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(
# /usr/local/lib/python3.10/dist-packages/squidpy/pl/_spatial_utils.py:976: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   _cax = scatter(

# %% [markdown]
#  Combine `sub_adata` with original `adata` object and transfer the sliding_window_assignment into original data.

# %%
adata_pancreas.obs['sliding_window_assignment'] = adata_pancreas.obs['ImageNumber'].astype(str)

# Get all unique categories from both sources
all_categories = list(set(adata_pancreas.obs['ImageNumber'].astype(str).unique()) | 
                     set(sub_adata.obs['sliding_window_assignment'].astype(str).unique()))

# Convert to categorical with all categories
adata_pancreas.obs['sliding_window_assignment'] = pd.Categorical(
    adata_pancreas.obs['sliding_window_assignment'],
    categories=all_categories
)

# Now update the subset
adata_pancreas.obs.loc[sub_adata.obs.index, 'sliding_window_assignment'] = sub_adata.obs['sliding_window_assignment'].astype(str)

# %%
# Store ImageNumbers with small windows
images_with_small_windows = []
all_window_counts = np.array([])

for img_nr in np.unique(adata_pancreas.obs['ImageNumber']):
    sub_adata = adata_pancreas[adata_pancreas.obs['ImageNumber'] == img_nr]
    window_counts = sub_adata.obs.groupby(['sliding_window_assignment']).size()
    all_window_counts = np.append(all_window_counts, window_counts.values)
    
    # Check if any window has < 500 cells
    small_windows = window_counts[window_counts < 500]
    
    if len(small_windows) > 0:
        images_with_small_windows.append(img_nr)
        print(f"\nImageNumber {img_nr}:")
        print(f"  Windows with < 500 cells: {len(small_windows)}")
        print(f"  Window counts:\n{window_counts}")

print(f"\n{'='*50}")
print(f"Total ImageNumbers with windows < 500 cells: {len(images_with_small_windows)}")
print(f"Affected ImageNumbers: {images_with_small_windows}")
# Out:
# ImageNumber 1:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 1_window_0    3174
# 1_window_1     301
# 1_window_3      99
# 1_window_2    1076
# dtype: int64
#
# ImageNumber 7:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 7_window_0    2691
# 7_window_1     464
# dtype: int64
#
# ImageNumber 14:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 14_window_0    2855
# 14_window_1     344
# dtype: int64
#
# ImageNumber 15:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 15_window_1      23
# 15_window_0    2551
# dtype: int64
#
# ImageNumber 16:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 16_window_0    3089
# 16_window_2     661
# 16_window_1     947
# 16_window_3     197
# dtype: int64
#
# ImageNumber 19:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 19_window_2    1435
# 19_window_1     100
# 19_window_0    3243
# 19_window_3      59
# dtype: int64
#
# ImageNumber 21:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 21_window_0    2909
# 21_window_1      63
# dtype: int64
#
# ImageNumber 22:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 22_window_1     293
# 22_window_0    3194
# dtype: int64
#
# ImageNumber 23:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 23_window_1     308
# 23_window_2    1364
# 23_window_0    3310
# 23_window_3     138
# dtype: int64
#
# ImageNumber 28:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 28_window_0    3442
# 28_window_1     449
# dtype: int64
#
# ImageNumber 33:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 33_window_1     252
# 33_window_0    3212
# dtype: int64
#
# ImageNumber 34:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 34_window_2    1729
# 34_window_3     260
# 34_window_1     488
# 34_window_0    3348
# dtype: int64
#
# ImageNumber 35:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 35_window_1      83
# 35_window_0    3668
# dtype: int64
#
# ImageNumber 36:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 36_window_0    3870
# 36_window_1     103
# dtype: int64
#
# ImageNumber 37:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 37_window_0    3172
# 37_window_1     786
# 37_window_3     295
# 37_window_2    1498
# dtype: int64
#
# ImageNumber 39:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 39_window_0    3134
# 39_window_1     304
# dtype: int64
#
# ImageNumber 40:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 40_window_0    3186
# 40_window_1     234
# dtype: int64
#
# ImageNumber 43:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 43_window_0    2619
# 43_window_1     239
# dtype: int64
#
# ImageNumber 48:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 48_window_1     202
# 48_window_0    3008
# dtype: int64
#
# ImageNumber 54:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 54_window_0    3405
# 54_window_3      50
# 54_window_1     668
# 54_window_2     265
# dtype: int64
#
# ImageNumber 57:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 57_window_1     358
# 57_window_0    3108
# dtype: int64
#
# ImageNumber 58:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 58_window_1     430
# 58_window_0    2870
# dtype: int64
#
# ImageNumber 68:
#   Windows with < 500 cells: 3
#   Window counts:
# sliding_window_assignment
# 68_window_0    3284
# 68_window_1     235
# 68_window_2      89
# 68_window_3       8
# dtype: int64
#
# ImageNumber 72:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 72_window_1      85
# 72_window_0    2952
# dtype: int64
#
# ImageNumber 88:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 88_window_1      35
# 88_window_0    2690
# dtype: int64
#
# ImageNumber 104:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 104_window_1    1114
# 104_window_3     388
# 104_window_2    1142
# 104_window_0    3485
# dtype: int64
#
# ImageNumber 138:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 138_window_1     185
# 138_window_0    2600
# dtype: int64
#
# ImageNumber 139:
#   Windows with < 500 cells: 3
#   Window counts:
# sliding_window_assignment
# 139_window_3       3
# 139_window_2      51
# 139_window_1     175
# 139_window_0    3595
# dtype: int64
#
# ImageNumber 140:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 140_window_0    2772
# 140_window_1     367
# dtype: int64
#
# ImageNumber 145:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 145_window_0    3681
# 145_window_1      20
# dtype: int64
#
# ImageNumber 157:
#   Windows with < 500 cells: 3
#   Window counts:
# sliding_window_assignment
# 157_window_0    3463
# 157_window_1     460
# 157_window_2     220
# 157_window_3      28
# dtype: int64
#
# ImageNumber 165:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 165_window_1     414
# 165_window_0    2669
# dtype: int64
#
# ImageNumber 174:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 174_window_1    1531
# 174_window_2     483
# 174_window_0    3751
# 174_window_3     171
# dtype: int64
#
# ImageNumber 178:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 178_window_0    3344
# 178_window_1     925
# 178_window_3      47
# 178_window_2     166
# dtype: int64
#
# ImageNumber 180:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 180_window_2     962
# 180_window_1     245
# 180_window_3      42
# 180_window_0    3111
# dtype: int64
#
# ImageNumber 190:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 190_window_2     762
# 190_window_0    2989
# 190_window_3      40
# 190_window_1     131
# dtype: int64
#
# ImageNumber 207:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 207_window_1      36
# 207_window_2     835
# 207_window_3       8
# 207_window_0    3716
# dtype: int64
#
# ImageNumber 212:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 212_window_1     133
# 212_window_2     534
# 212_window_3      16
# 212_window_0    3451
# dtype: int64
#
# ImageNumber 213:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 213_window_2    1506
# 213_window_1     846
# 213_window_3     345
# 213_window_0    3266
# dtype: int64
#
# ImageNumber 214:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 214_window_1      57
# 214_window_0    3261
# dtype: int64
#
# ImageNumber 216:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 216_window_1     404
# 216_window_0    3384
# dtype: int64
#
# ImageNumber 219:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 219_window_0    2330
# 219_window_1     413
# dtype: int64
#
# ImageNumber 225:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 225_window_0    2602
# 225_window_1      56
# dtype: int64
#
# ImageNumber 232:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 232_window_0    2844
# 232_window_1     423
# dtype: int64
#
# ImageNumber 234:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 234_window_1     289
# 234_window_0    2294
# dtype: int64
#
# ImageNumber 237:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 237_window_2     328
# 237_window_3     194
# 237_window_1    1867
# 237_window_0    3331
# dtype: int64
#
# ImageNumber 247:
#   Windows with < 500 cells: 3
#   Window counts:
# sliding_window_assignment
# 247_window_2     242
# 247_window_0    3055
# 247_window_1     252
# 247_window_3      16
# dtype: int64
#
# ImageNumber 257:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 257_window_0    2640
# 257_window_1     191
# dtype: int64
#
# ImageNumber 259:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 259_window_0    3051
# 259_window_1     340
# dtype: int64
#
# ImageNumber 287:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 287_window_2     277
# 287_window_3      53
# 287_window_1     738
# 287_window_0    3885
# dtype: int64
#
# ImageNumber 290:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 290_window_1     492
# 290_window_0    2434
# dtype: int64
#
# ImageNumber 292:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 292_window_0    2827
# 292_window_1     106
# dtype: int64
#
# ImageNumber 295:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 295_window_1     352
# 295_window_0    3312
# dtype: int64
#
# ImageNumber 305:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 305_window_0    2640
# 305_window_1     166
# dtype: int64
#
# ImageNumber 308:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 308_window_0    2808
# 308_window_1     244
# dtype: int64
#
# ImageNumber 314:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 314_window_1      11
# 314_window_0    2652
# dtype: int64
#
# ImageNumber 321:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 321_window_1      45
# 321_window_0    2881
# dtype: int64
#
# ImageNumber 333:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 333_window_1      36
# 333_window_0    2710
# dtype: int64
#
# ImageNumber 342:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 342_window_1     340
# 342_window_0    2186
# dtype: int64
#
# ImageNumber 355:
#   Windows with < 500 cells: 3
#   Window counts:
# sliding_window_assignment
# 355_window_3      27
# 355_window_2     364
# 355_window_1     240
# 355_window_0    3687
# dtype: int64
#
# ImageNumber 359:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 359_window_0    2915
# 359_window_3      41
# 359_window_2    1327
# 359_window_1      82
# dtype: int64
#
# ImageNumber 360:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 360_window_2    1073
# 360_window_3     178
# 360_window_1     140
# 360_window_0    2542
# dtype: int64
#
# ImageNumber 366:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 366_window_0    2761
# 366_window_1      69
# dtype: int64
#
# ImageNumber 372:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 372_window_3      84
# 372_window_1     325
# 372_window_2     677
# 372_window_0    3072
# dtype: int64
#
# ImageNumber 375:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 375_window_0    2711
# 375_window_1      78
# dtype: int64
#
# ImageNumber 378:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 378_window_3     318
# 378_window_0    2926
# 378_window_1    1035
# 378_window_2     911
# dtype: int64
#
# ImageNumber 383:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 383_window_3     148
# 383_window_0    2196
# 383_window_1     222
# 383_window_2    1479
# dtype: int64
#
# ImageNumber 394:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 394_window_1    1074
# 394_window_0    2895
# 394_window_3     381
# 394_window_2    1068
# dtype: int64
#
# ImageNumber 395:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 395_window_1     417
# 395_window_0    2817
# dtype: int64
#
# ImageNumber 396:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 396_window_1     763
# 396_window_3     124
# 396_window_0    2710
# 396_window_2     754
# dtype: int64
#
# ImageNumber 402:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 402_window_3      85
# 402_window_1     192
# 402_window_2    1397
# 402_window_0    3133
# dtype: int64
#
# ImageNumber 403:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 403_window_1     352
# 403_window_2     778
# 403_window_3      87
# 403_window_0    2797
# dtype: int64
#
# ImageNumber 411:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 411_window_0    2836
# 411_window_2    1541
# 411_window_1     513
# 411_window_3     254
# dtype: int64
#
# ImageNumber 413:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 413_window_3     361
# 413_window_2    1070
# 413_window_0    3202
# 413_window_1    1172
# dtype: int64
#
# ImageNumber 445:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 445_window_0    3401
# 445_window_1     127
# dtype: int64
#
# ImageNumber 461:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 461_window_1     407
# 461_window_0    4606
# dtype: int64
#
# ImageNumber 466:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 466_window_1     135
# 466_window_0    3635
# dtype: int64
#
# ImageNumber 467:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 467_window_0    3815
# 467_window_1     448
# dtype: int64
#
# ImageNumber 493:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 493_window_1     310
# 493_window_0    3172
# dtype: int64
#
# ImageNumber 517:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 517_window_2     689
# 517_window_1     960
# 517_window_0    2866
# 517_window_3     217
# dtype: int64
#
# ImageNumber 530:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 530_window_1     410
# 530_window_0    2103
# dtype: int64
#
# ImageNumber 553:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 553_window_0    3079
# 553_window_1      22
# 553_window_3       4
# 553_window_2     645
# dtype: int64
#
# ImageNumber 557:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 557_window_1     344
# 557_window_0    2615
# dtype: int64
#
# ImageNumber 569:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 569_window_1     711
# 569_window_3     318
# 569_window_0    2871
# 569_window_2    1127
# dtype: int64
#
# ImageNumber 573:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 573_window_0    2281
# 573_window_1     226
# dtype: int64
#
# ImageNumber 575:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 575_window_0    2459
# 575_window_1     395
# dtype: int64
#
# ImageNumber 579:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 579_window_0    2969
# 579_window_2      49
# 579_window_3       9
# 579_window_1     601
# dtype: int64
#
# ImageNumber 604:
#   Windows with < 500 cells: 3
#   Window counts:
# sliding_window_assignment
# 604_window_1      61
# 604_window_3      10
# 604_window_0    2744
# 604_window_2     324
# dtype: int64
#
# ImageNumber 610:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 610_window_1     439
# 610_window_0    2660
# dtype: int64
#
# ImageNumber 623:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 623_window_0    2714
# 623_window_1     162
# dtype: int64
#
# ImageNumber 641:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 641_window_0    2728
# 641_window_1     222
# dtype: int64
#
# ImageNumber 644:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 644_window_1      25
# 644_window_0    2829
# dtype: int64
#
# ImageNumber 655:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 655_window_1     234
# 655_window_0    3258
# dtype: int64
#
# ImageNumber 682:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 682_window_1     468
# 682_window_0    3357
# dtype: int64
#
# ImageNumber 693:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 693_window_0    3205
# 693_window_1     334
# dtype: int64
#
# ImageNumber 694:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 694_window_1     348
# 694_window_0    3498
# dtype: int64
#
# ImageNumber 706:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 706_window_1     306
# 706_window_0    2332
# dtype: int64
#
# ImageNumber 708:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 708_window_0    3022
# 708_window_1     215
# dtype: int64
#
# ImageNumber 710:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 710_window_1     122
# 710_window_0    2841
# dtype: int64
#
# ImageNumber 725:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 725_window_1      96
# 725_window_0    3172
# dtype: int64
#
# ImageNumber 744:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 744_window_0    3582
# 744_window_2     434
# 744_window_3      82
# 744_window_1     655
# dtype: int64
#
# ImageNumber 752:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 752_window_0    3587
# 752_window_2     258
# 752_window_1    1056
# 752_window_3      59
# dtype: int64
#
# ImageNumber 758:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 758_window_3     108
# 758_window_1     225
# 758_window_0    3692
# 758_window_2    1675
# dtype: int64
#
# ImageNumber 762:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 762_window_1     158
# 762_window_0    2390
# dtype: int64
#
# ImageNumber 781:
#   Windows with < 500 cells: 3
#   Window counts:
# sliding_window_assignment
# 781_window_1      63
# 781_window_0    3271
# 781_window_2     488
# 781_window_3       6
# dtype: int64
#
# ImageNumber 782:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 782_window_1     131
# 782_window_0    3531
# dtype: int64
#
# ImageNumber 785:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 785_window_0    2858
# 785_window_1      88
# dtype: int64
#
# ImageNumber 787:
#   Windows with < 500 cells: 3
#   Window counts:
# sliding_window_assignment
# 787_window_5       8
# 787_window_4     750
# 787_window_0    3400
# 787_window_3     468
# 787_window_2    3471
# 787_window_1     493
# dtype: int64
#
# ImageNumber 788:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 788_window_1     175
# 788_window_2    2712
# 788_window_0    3616
# 788_window_3     104
# dtype: int64
#
# ImageNumber 789:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 789_window_1     192
# 789_window_0    3520
# dtype: int64
#
# ImageNumber 793:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 793_window_3     425
# 793_window_2    1454
# 793_window_0    3451
# 793_window_1     867
# dtype: int64
#
# ImageNumber 794:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 794_window_0    3830
# 794_window_1     457
# 794_window_2     644
# 794_window_3      79
# dtype: int64
#
# ImageNumber 796:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 796_window_0    3358
# 796_window_3      38
# 796_window_1    1026
# 796_window_2     129
# dtype: int64
#
# ImageNumber 800:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 800_window_0    3172
# 800_window_1     212
# dtype: int64
#
# ImageNumber 808:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 808_window_1     160
# 808_window_0    2602
# dtype: int64
#
# ImageNumber 809:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 809_window_1     264
# 809_window_0    2524
# dtype: int64
#
# ImageNumber 816:
#   Windows with < 500 cells: 3
#   Window counts:
# sliding_window_assignment
# 816_window_2     197
# 816_window_3       2
# 816_window_1      48
# 816_window_0    3533
# dtype: int64
#
# ImageNumber 818:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 818_window_0    3295
# 818_window_1     331
# dtype: int64
#
# ImageNumber 819:
#   Windows with < 500 cells: 3
#   Window counts:
# sliding_window_assignment
# 819_window_2     179
# 819_window_0    3460
# 819_window_3       4
# 819_window_1      30
# dtype: int64
#
# ImageNumber 820:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 820_window_3     226
# 820_window_1     350
# 820_window_2    1501
# 820_window_0    3096
# dtype: int64
#
# ImageNumber 822:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 822_window_1     350
# 822_window_0    2869
# dtype: int64
#
# ImageNumber 823:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 823_window_1      25
# 823_window_0    3377
# 823_window_2    1109
# 823_window_3      53
# dtype: int64
#
# ImageNumber 825:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 825_window_1     144
# 825_window_0    2412
# dtype: int64
#
# ImageNumber 829:
#   Windows with < 500 cells: 2
#   Window counts:
# sliding_window_assignment
# 829_window_3      60
# 829_window_1     134
# 829_window_2    1586
# 829_window_0    3571
# dtype: int64
#
# ImageNumber 834:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 834_window_1     251
# 834_window_0    2768
# dtype: int64
#
# ImageNumber 837:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 837_window_1     435
# 837_window_0    2114
# dtype: int64
#
# ImageNumber 839:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 839_window_0    2734
# 839_window_1     102
# dtype: int64
#
# ImageNumber 843:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 843_window_0    2733
# 843_window_1     247
# dtype: int64
#
# ImageNumber 844:
#   Windows with < 500 cells: 1
#   Window counts:
# sliding_window_assignment
# 844_window_1     461
# 844_window_0    3172
# dtype: int64
#
# ==================================================
# Total ImageNumbers with windows < 500 cells: 129
# Affected ImageNumbers: [1, 7, 14, 15, 16, 19, 21, 22, 23, 28, 33, 34, 35, 36, 37, 39, 40, 43, 48, 54, 57, 58, 68, 72, 88, 104, 138, 139, 140, 145, 157, 165, 174, 178, 180, 190, 207, 212, 213, 214, 216, 219, 225, 232, 234, 237, 247, 257, 259, 287, 290, 292, 295, 305, 308, 314, 321, 333, 342, 355, 359, 360, 366, 372, 375, 378, 383, 394, 395, 396, 402, 403, 411, 413, 445, 461, 466, 467, 493, 517, 530, 553, 557, 569, 573, 575, 579, 604, 610, 623, 641, 644, 655, 682, 693, 694, 706, 708, 710, 725, 744, 752, 758, 762, 781, 782, 785, 787, 788, 789, 793, 794, 796, 800, 808, 809, 816, 818, 819, 820, 822, 823, 825, 829, 834, 837, 839, 843, 844]

# %%
# Create the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot histogram
ax.hist(all_window_counts, bins=50, edgecolor='black', alpha=0.7)

# Labels and title
ax.set_xlabel('Number of cells per window', fontsize=12)
ax.set_ylabel('Number of windows', fontsize=12)
ax.set_title('Distribution of cells per Image', fontsize=14, fontweight='bold')

# Add grid for better readability
ax.grid(axis='y', alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# %% [markdown]
# Remove `Images` with a sliding window having a low number of cells.

# %%
adata_pancreas = adata_pancreas[~adata_pancreas.obs['ImageNumber'].isin(images_with_small_windows)]
adata_pancreas.shape
# Out:
# (1283580, 38)

# %%
tissue_cell_number = adata_pancreas.obs.groupby('sliding_window_assignment').size()
print(f"Nr cells per sliding window: Min: {tissue_cell_number.min()}, Max: {tissue_cell_number.max()}, Avg: {tissue_cell_number.mean()}")
# Out:
# Nr cells per sliding window: Min: 521, Max: 3975, Avg: 1620.6818181818182

# %% [markdown]
# ## 4. Split data into train and val set
#
# Training the model requires a `split` assignment for each donor/patient/sliding window that you wanna train on.

# %%
from sklearn.model_selection import train_test_split

# %%
cases_by_stage = adata_pancreas.obs.groupby('stage')['case'].unique()
cases_by_stage
# Out:
# stage
# Long-duration    [6418, 6180, 6089, 6264]
# Non-diabetic     [6126, 6134, 6386, 6278]
# Onset            [6362, 6414, 6228, 6380]
# Name: case, dtype: object

# %%
adata_pancreas.obs['split'] = None

for i, split_name in enumerate(['test', 'val', 'train']):
    if split_name == 'train':
        # For train, use all remaining cases (from index i onwards)
        train_cases = list(cases_by_stage['Long-duration'][i:]) + \
                     list(cases_by_stage['Non-diabetic'][i:]) + \
                     list(cases_by_stage['Onset'][i:])
        adata_pancreas.obs.loc[adata_pancreas.obs['case'].isin(train_cases), 'split'] = split_name
    else:
        # For test and val, use single cases
        split_cases = [cases_by_stage['Long-duration'][i], 
                      cases_by_stage['Non-diabetic'][i], 
                      cases_by_stage['Onset'][i]]
        adata_pancreas.obs.loc[adata_pancreas.obs['case'].isin(split_cases), 'split'] = split_name

# %%
adata_pancreas.obs.groupby(['case', 'split']).size()
# Out:
# case  split
# 6089  train     77680
# 6126  test     119290
# 6134  val      121526
# 6180  val      105937
# 6228  train    122050
# 6264  train    114866
# 6278  train     88231
# 6362  test     116649
# 6380  train    106312
# 6386  train    104220
# 6414  val      117496
# 6418  test      89323
# dtype: int64

# %%
adata_pancreas.obs.groupby(['stage', 'split']).size()
# Out:
# stage          split
# Long-duration  test      89323
#                train    192546
#                val      105937
# Non-diabetic   test     119290
#                train    192451
#                val      121526
# Onset          test     116649
#                train    228362
#                val      117496
# dtype: int64

# %% [markdown]
# ## Save adata object
#
# Save the prepared adata object such that it can be loaded for the model training.

# %%
adata_pancreas.write('/dss/dssfs03/tumdss/pn36po/pn36po-dss-0002/di93tig/Projects/A3_InterScale/data/damond19_pp.h5ad')

# %% [markdown]
# ## Prepare config file
#
# Duplicate the minum requirement config file from `/GT-long-range-niches/src/config_files/InterScale_example.yaml` and add the necessary specification for the Visum data:
#
# ```
# model:
#   local_component:
#     name: GCN
#   global_component:
#     name: self-attn-transformer
#         max_seq_len: 2418
#   save: /path/to/save/model/
# dataset:
#   h5ad_data: visium_tme_pp.h5ad
#   name: Visium_breast_cancer_TME
#   sample_key: ['batch']
#   spatial_neigbors_kwargs:
#     coord_type: grid
#     library_key: batch
# ```
#
#
# Save the config file as `.yaml` and proceed to training (either interactively in jupyter notebook or by running a script).
