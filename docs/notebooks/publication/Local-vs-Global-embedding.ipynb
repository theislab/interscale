# %% [markdown]
# # Local vs Global Embedding
#
# Goal: Compare the local and global embeddings based on clustering.
# Idea:
#
# - ARI
# - AMI
# - homogeneity score
#
# Hypothesis: The local and global embeddings are vary, meaning that they do not capture the same information.
