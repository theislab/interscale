# %% [markdown]
# # InterScale API for developers

# %% [markdown]
# The InterScale repository/library is inspired by [scvi-tools][https://github.com/scverse/scvi-tools/tree/main] and [GraphGPS]().
#
# The main structure is:

# %% [markdown]
# ```python
# class model():
#     def train():

# %% [markdown]
# ## Adding local/global module
#
# 1. New Python file with `class new_module(LocalComponent)` or `class new_module(LocalComponent)`. Define `__init__()` and `forward()` function.
# 2. Add necessary default configuration values to `/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/InterScale/config/local_component_config.py`
# 3.
#
# ### Local Component
#
# Input:
# - GEX matrix (NxF)
# - Adjacency matrix (NxN)
#
# Output:
# - Embedding (NxE)
