# %%
# import sys
# print(sys.path)

# %%
from graph_transformer_long_range_niches.tl.utils import pad_batch
from graph_transformer_long_range_niches.model.gnn_transformer import LitGNNTransformer
from graph_transformer_long_range_niches.tl.load_config import Config
from graph_transformer_long_range_niches.main import main
from graph_transformer_long_range_niches.pp.geome_utils import prepare_geome_dataset
from graph_transformer_long_range_niches.config import load_config

import yaml
import torch
import wandb
import numpy as np

from torch_geometric.loader import DataLoader
from torch_geometric.data import Data

# %%
# get CLS token 

shape = (2,3,4)
transformer_out = torch.rand(shape)
cls = transformer_out[-1,:, :]
transformer_out, cls.shape
# Out:
# (tensor([[[0.7835, 0.2479, 0.6750, 0.9469],
#           [0.0418, 0.1142, 0.2636, 0.7519],
#           [0.0496, 0.3847, 0.6680, 0.2610]],
#
#          [[0.1482, 0.1174, 0.9778, 0.0584],
#           [0.4113, 0.2554, 0.9674, 0.4066],
#           [0.9466, 0.4160, 0.5444, 0.6399]]]),
#  torch.Size([3, 4]))

# %%
cfg_pancreas = '/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/pancreas_gnntrans_ct_toy.yaml'
pancreas_graph = '/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/pancreas_gnntrans_graph_condition.yaml'
default_cfg = '/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/default_configs.yaml'

# %%
main(pancreas_graph)
# Out:
# Load PyG data...
# call new
# /ictstr01/home/icb/francesca.drummer/1-Projects/geome/src/geome/transforms/categorize.py:38: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   getattr(adata, self.axis)[key] = getattr(adata, self.axis)[key].astype("category")
# {'condition': ['ND', 'T1D']}
# [Data(x=[814, 979], edge_index=[2, 826], y=[814, 2], obs_names=[814]), Data(x=[727, 979], edge_index=[2, 696], y=[727, 2], obs_names=[727]), Data(x=[918, 979], edge_index=[2, 940], y=[918, 2], obs_names=[918])]
# 144
# train ds: 115, val ds: 29
# Load GNNTransfomer...
# Training...
# /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/torch_geometric/data/lightning/datamodule.py:43: The 'shuffle=True' option is ignored in 'LightningDataset'. Remove it from the argument list to disable this warning
# /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/lightning_fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /ictstr01/groups/ml01/workspace/francesca.drummer/ma ...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:75: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#
#    | Name                   | Type                   | Params | Mode
# ---------------------------------------------------------------------------
# 0  | gnn2transformer        | Linear                 | 32.9 K | train
# 1  | norm_input             | LayerNorm              | 256    | train
# 2  | loss                   | CrossEntropyLoss       | 0      | train
# 3  | accurary               | MulticlassAccuracy     | 0      | train
# 4  | f1_score_micro         | MulticlassF1Score      | 0      | train
# 5  | f1_score_macro         | MulticlassF1Score      | 0      | train
# 6  | f1_score_per_class     | MulticlassF1Score      | 0      | train
# 7  | gnn                    | LitGCN                 | 317 K  | train
# 8  | transformer_encoder    | TransformerNodeEncoder | 198 K  | train
# 9  | graph_pred_linear_list | ModuleList             | 0      | train
# 10 | graph_pred_linear      | Linear                 | 258    | train
#    | other params           | n/a                    | 128    | n/a
# ---------------------------------------------------------------------------
# 549 K     Trainable params
# 0         Non-trainable params
# 549 K     Total params
# 2.199     Total estimated model params size (MB)
# TransformerEncoder output:  torch.Size([1001, 20, 128])
# cls:  torch.Size([20, 128])
# graph prediction:  torch.Size([20, 2])
# out_transformer tensor([[-0.2752, -0.0429],
#         [-0.3492, -0.0061],
#         [-0.2980,  0.0960],
#         [-0.2855, -0.0319],
#         [-0.3477,  0.0723],
#         [-0.3208,  0.0455],
#         [-0.2705,  0.0120],
#         [-0.2722, -0.0099],
#         [-0.2952,  0.0699],
#         [-0.2910,  0.0280],
#         [-0.3840, -0.0025],
#         [-0.3327,  0.0899],
#         [-0.2606,  0.0277],
#         [-0.2621, -0.0211],
#         [-0.3117,  0.0237],
#         [-0.2996,  0.0095],
#         [-0.2857,  0.0110],
#         [-0.2821,  0.0335],
#         [-0.2822, -0.0443],
#         [-0.2932,  0.0814]])
# y_true [tensor(0.), tensor(1.)]
# y_true tensor([1., 1.])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 main(pancreas_graph)
#
# File /ictstr01/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/graph_transformer_long_range_niches/main.py:101, in main(cfg_path)
#      90     print('Training...')
#      91     trainer = pl.Trainer(min_epochs=1,
#      92                      max_epochs=int(cfg.model.n_epochs),
#      93                      enable_progress_bar=False,
#    (...)
#      97                      #overfit_batches=1,
#      98                      )
# --> 101 trainer.fit(model, dm)
#     102 trainer.validate(model, dm)
#     104 if cfg.wandb.use:
#     105     ## log model artifact
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:543, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     541 self.state.status = TrainerStatus.RUNNING
#     542 self.training = True
# --> 543 call._call_and_handle_interrupt(
#     544     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     545 )
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      42     if trainer.strategy.launcher is not None:
#      43         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 44     return trainer_fn(*args, **kwargs)
#      46 except _TunerExitException:
#      47     _call_teardown_hook(trainer)
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:579, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     572 assert self.state.fn is not None
#     573 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     574     self.state.fn,
#     575     ckpt_path,
#     576     model_provided=True,
#     577     model_connected=self.lightning_module is not None,
#     578 )
# --> 579 self._run(model, ckpt_path=ckpt_path)
#     581 assert self.state.stopped
#     582 self.training = False
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:986, in Trainer._run(self, model, ckpt_path)
#     981 self._signal_connector.register_signal_handlers()
#     983 # ----------------------------
#     984 # RUN THE TRAINER
#     985 # ----------------------------
# --> 986 results = self._run_stage()
#     988 # ----------------------------
#     989 # POST-Training CLEAN UP
#     990 # ----------------------------
#     991 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:1028, in Trainer._run_stage(self)
#    1026 if self.training:
#    1027     with isolate_rng():
# -> 1028         self._run_sanity_check()
#    1029     with torch.autograd.set_detect_anomaly(self._detect_anomaly):
#    1030         self.fit_loop.run()
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:1057, in Trainer._run_sanity_check(self)
#    1054 call._call_callback_hooks(self, "on_sanity_check_start")
#    1056 # run eval step
# -> 1057 val_loop.run()
#    1059 call._call_callback_hooks(self, "on_sanity_check_end")
#    1061 # reset logger connector
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/loops/utilities.py:182, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     180     context_manager = torch.no_grad
#     181 with context_manager():
# --> 182     return loop_run(self, *args, **kwargs)
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/loops/evaluation_loop.py:135, in _EvaluationLoop.run(self)
#     133     self.batch_progress.is_last_batch = data_fetcher.done
#     134     # run step hooks
# --> 135     self._evaluation_step(batch, batch_idx, dataloader_idx, dataloader_iter)
#     136 except StopIteration:
#     137     # this needs to wrap the `*_step` call too (not just `next`) for `dataloader_iter` support
#     138     break
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/loops/evaluation_loop.py:396, in _EvaluationLoop._evaluation_step(self, batch, batch_idx, dataloader_idx, dataloader_iter)
#     390 hook_name = "test_step" if trainer.testing else "validation_step"
#     391 step_args = (
#     392     self._build_step_args_from_hook_kwargs(hook_kwargs, hook_name)
#     393     if not using_dataloader_iter
#     394     else (dataloader_iter,)
#     395 )
# --> 396 output = call._call_strategy_hook(trainer, hook_name, *step_args)
#     398 self.batch_progress.increment_processed()
#     400 if using_dataloader_iter:
#     401     # update the hook kwargs now that the step method might have consumed the iterator
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:311, in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     308     return None
#     310 with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 311     output = fn(*args, **kwargs)
#     313 # restore current_fx when nested context
#     314 pl_module._current_fx_name = prev_fx_name
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range/lib/python3.11/site-packages/pytorch_lightning/strategies/strategy.py:411, in Strategy.validation_step(self, *args, **kwargs)
#     409 if self.model != self.lightning_module:
#     410     return self._forward_redirection(self.model, self.lightning_module, "validation_step", *args, **kwargs)
# --> 411 return self.lightning_module.validation_step(*args, **kwargs)
#
# File /ictstr01/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/graph_transformer_long_range_niches/model/gnn_transformer.py:139, in LitGNNTransformer.validation_step(self, batch, batch_idx)
#     138 def validation_step(self, batch, batch_idx):
# --> 139     loss, acc, f1_score_micro, f1_score_macro, f1_score_per_class = self._common_step(batch)
#     140     log_dict = {
#     141         'val_loss': loss,
#     142         'val_acc': acc,
#     143         'val_f1_micro/avg': f1_score_micro,
#     144         'val_f1_macro/avg': f1_score_macro,
#     145     }
#     146     for class_idx in range(self.num_classes):
#
# File /ictstr01/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/graph_transformer_long_range_niches/model/gnn_transformer.py:173, in LitGNNTransformer._common_step(self, batch)
#     171         raise Exception('Choose a valid prediction tasks (graph or node).')
#     172     print("y_true", y_true)
# --> 173     y_true = torch.stack(y_true)
#     175 print("y_true: ", y_true)
#     176 #print('predicted and true: ', out_transformer[:10].argmax(dim=1), y_true[:10].argmax(dim=1))
#
# TypeError: stack(): argument 'tensors' (position 1) must be tuple of Tensors, not Tensor

# %%
cfg = Config(cfg_he23_cosmx_lung_0, default_path='/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/default_configs.yaml')

# load PyTorch Geometric object
data, slices = torch.load(cfg.get('dataset/data_path'))
# Out:
# Load cfg file...
# {'out_dir': 'results', 'wandb': {'use': False, 'project_name': 'GTLongRange', 'run_idx': None}, 'model': {'model_type': 'gnn-transformer', 'lr': 0.1, 'wd': 0.0005, 'n_epochs': 20}, 'dataset': {'data_path': '/home/icb/francesca.drummer/1-Projects/DLS_graphTransformer/Exphormer/datasets/he22_cosmx_human_lung_subdataniche/sub_graph_medium_0/niche/processed/train.pt', 'data_name': 'he23_comsx_human_lung', 'prediction_task': 'node', 'num_classes': 9}, 'gnn': {'gnn_type': 'GCN', 'num_layers': 2, 'num_features': 960, 'hidden_dim': 256, 'embed_dim': 256}, 'transformer': {'d_model': 128, 'n_heads': 4, 'dim_feedforward': 512, 'dropout': 0.3, 'num_layers': 4, 'activation_func': 'relu', 'num_encoder_layers': 4, 'max_input_len': 1000}}

# %%
dataset = prepare_dataset(data, slices)
print(len(dataset))
train_loader = DataLoader(dataset, batch_size=100)
for batch in train_loader:
    print(batch)
    break
# Out:
# 98002
# DataBatch(x=[24641, 960], edge_index=[2, 432106], edge_attr=[432106], y=[24641], batch=[24641], ptr=[101])

# %%
wandb_use = bool(cfg.get('wandb/use'))
if wandb_use:
    print('Wandb initialize...')
    wandb.init(project=cfg.get('wandb/project_name'))

# %%
# model initialization
if cfg.get('model/model_type') == 'gnn-transformer':
    print('Load GNNTransfomer...')
    model = GNNTransformer(cfg)

# %%
path_lung_full = '/home/icb/francesca.drummer/1-Projects/DLS_graphTransformer/Exphormer/datasets/He22CosmxHumanLung/full_graph_niche/processed/data.pt'
path_lung_subgraph = '/home/icb/francesca.drummer/1-Projects/DLS_graphTransformer/Exphormer/datasets/He22CosmxHumanLung/sub_graph_medium_niche_30/processed/train.pt'

# %%
lung_data, lung_slices = torch.load(path_lung_subgraph)

# %%
lung_data
# Out:
# Data(x=[54377, 960], edge_index=[2, 57406], edge_attr=[57406], y=[54377])

# %%
lung_slices
# Out:
# defaultdict(dict,
#             {'x': tensor([    0,     2,     4,  ..., 54373, 54375, 54377]),
#              'edge_index': tensor([    0,     2,     4,  ..., 57402, 57404, 57406]),
#              'edge_attr': tensor([    0,     2,     4,  ..., 57402, 57404, 57406]),
#              'y': tensor([    0,     2,     4,  ..., 54373, 54375, 54377])})

# %%
lung_datasets = prepare_dataset(lung_data, lung_slices)
lung_datasets
# Out:
# [Data(x=[98002, 960], edge_index=[2, 6168], edge_attr=[6168], y=[98002]),
#  Data(x=[105800, 960], edge_index=[2, 8250], edge_attr=[8250], y=[105800]),
#  Data(x=[97809, 960], edge_index=[2, 6126], edge_attr=[6126], y=[97809]),
#  Data(x=[89975, 960], edge_index=[2, 1520], edge_attr=[1520], y=[89975]),
#  Data(x=[87606, 960], edge_index=[2, 5456], edge_attr=[5456], y=[87606]),
#  Data(x=[139504, 960], edge_index=[2, 6052], edge_attr=[6052], y=[139504]),
#  Data(x=[71304, 960], edge_index=[2, 3528], edge_attr=[3528], y=[71304]),
#  Data(x=[81236, 960], edge_index=[2, 8446], edge_attr=[8446], y=[81236])]

# %%
# Calculate accuracy
def accuracy(pred_y, y):
    return (pred_y == y).sum() / len(y)

def train(train_loader, model, optimizer, criterion, cfg_dict, N_EPOCHS=20):

    with wandb.init(project = 'GTLongRange', config = cfg_dict):
    
        # Data for animations
        embeddings = []
        losses = []
        accuracies_transformer = []
        accuracies_gnn = []
        outputs = []
    
        # Training loop
        for epoch in range(N_EPOCHS):
            curr_acc_trans = []
            curr_acc_gnn = []
            curr_loss = []
            for idx, batch in enumerate(train_loader): 
                # Clear gradients
                optimizer.zero_grad()
    
                # print(batch)
    
                # Forward pass
                out_gnn, out_transformer, index_nodes = model(batch) # [B, C] with C being the number of tasks to predict, e.i. 
    
                # In case of multiple graphs in one batch -> merge the index lists
                # for i in range(batch.batch[-1]+1):
                    
                # Calculate loss function
                loss = criterion(out_transformer, batch.y[index_nodes])
    
                # Calculate accuracy
                #print('Predicted label: ', out.argmax(dim=1), 'True label', batch.y)
                acc_transformer = accuracy(out_transformer.argmax(dim=1), batch.y[index_nodes])
                acc_gnn = accuracy(out_gnn.argmax(dim=1), batch.y)
    
                # Compute gradients
                loss.backward(retain_graph=True)
    
                # Tune parameters
                optimizer.step()
    
                # Store data for animations
                #embeddings.append(h)
                curr_loss.append(loss.detach().item())
                curr_acc_trans.append(acc_transformer)
                curr_acc_gnn.append(acc_gnn)
                outputs.append(out_transformer.argmax(dim=1))
    
            # Print metrics every 10 epochs
            if epoch % 5 == 0:
                print(f'Transformer Epoch {epoch:>3} | Loss: {np.mean(curr_loss):.2f} | GNN acc: {np.mean(curr_acc_gnn)*100:.2f}% | Trans acc: {np.mean(curr_acc_trans)*100:.2f}%')
                wandb.log({"epoch": epoch,
                          "loss": np.mean(curr_loss),
                          "acc GNN": np.mean(curr_acc_gnn),
                          "acc Transformer": np.mean(curr_acc_trans)})
                accuracies_transformer.append(np.mean(curr_acc_trans))
                accuracies_gnn.append(np.mean(curr_acc_gnn))
                losses.append(np.mean(curr_loss))

    wandb.finish()

    return accuracies_transformer, accuracies_gnn

# %%
cfg_path = '/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/he23_lung.yaml'

with open(cfg_path) as stream:
    cfg_dict = yaml.safe_load(stream)

train_loader_lung = DataLoader(lung_datasets, batch_size=1) # merges batch_size graphs from a PyG dataset 
    
gnn_transformer_model = GNNTransformer(cfg_dict)
lr = 0.1
weight_decay = 5e-4
optimizer = torch.optim.Adam(gnn_transformer_model.parameters(), lr=lr, weight_decay=weight_decay)
criterion = torch.nn.CrossEntropyLoss()

# %%
accuracies_transformer, accuracies_gnn = train(train_loader_lung, gnn_transformer_model, optimizer, criterion, cfg_dict, N_EPOCHS=200)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: francesca-drummer. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/docs/notebooks/wandb/run-20240321_104948-m2i92rsr</code>
# Syncing run <strong><a href='https://wandb.ai/francesca-drummer/GTLongRange/runs/m2i92rsr' target="_blank">stellar-bird-14</a></strong> to <a href='https://wandb.ai/francesca-drummer/GTLongRange' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/francesca-drummer/GTLongRange' target="_blank">https://wandb.ai/francesca-drummer/GTLongRange</a>
#  View run at <a href='https://wandb.ai/francesca-drummer/GTLongRange/runs/m2i92rsr' target="_blank">https://wandb.ai/francesca-drummer/GTLongRange/runs/m2i92rsr</a>
# Transformer Epoch   0 | Loss: 10.69 | GNN acc: 14.10% | Trans acc: 11.18%
# Transformer Epoch   5 | Loss: 2.15 | GNN acc: 15.92% | Trans acc: 30.70%
# Transformer Epoch  10 | Loss: 2.01 | GNN acc: 15.92% | Trans acc: 33.07%
# Transformer Epoch  15 | Loss: 2.00 | GNN acc: 15.26% | Trans acc: 32.20%
# Transformer Epoch  20 | Loss: 2.00 | GNN acc: 11.94% | Trans acc: 32.70%
# Transformer Epoch  25 | Loss: 2.00 | GNN acc: 10.89% | Trans acc: 32.11%
# Transformer Epoch  30 | Loss: 1.98 | GNN acc: 3.64% | Trans acc: 33.43%
# Transformer Epoch  35 | Loss: 1.97 | GNN acc: 6.18% | Trans acc: 33.86%
# Transformer Epoch  40 | Loss: 1.97 | GNN acc: 3.55% | Trans acc: 33.61%
# Transformer Epoch  45 | Loss: 2.07 | GNN acc: 3.55% | Trans acc: 25.56%
# Transformer Epoch  50 | Loss: 2.85 | GNN acc: 5.07% | Trans acc: 18.58%
# Transformer Epoch  55 | Loss: 2.99 | GNN acc: 3.55% | Trans acc: 20.99%
# Transformer Epoch  60 | Loss: 2.57 | GNN acc: 3.55% | Trans acc: 9.16%
# Transformer Epoch  65 | Loss: 2.04 | GNN acc: 3.55% | Trans acc: 33.10%
# Transformer Epoch  70 | Loss: 2.04 | GNN acc: 3.55% | Trans acc: 33.05%
# Transformer Epoch  75 | Loss: 2.03 | GNN acc: 33.04% | Trans acc: 32.48%
# Transformer Epoch  80 | Loss: 1.99 | GNN acc: 12.16% | Trans acc: 33.04%
# Transformer Epoch  85 | Loss: 1.98 | GNN acc: 7.78% | Trans acc: 32.86%

# %%
accuracies_gnn

# %% [markdown]
# Set up WandB

# %%
#train(train_loader, gnn_transformer_model, optimizer, criterion, N_EPOCHS=20)

# %% [markdown]
# ## Config file

# %%
cfg_path = '/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/test.yaml'

# %%
with open(cfg_path) as stream:
    cfg_dict = yaml.safe_load(stream)

# %%
cfg_dict
# Out:
# {'out_dir': 'results',
#  'dataloader': {'data_path': '', 'radius': 30},
#  'dataset': {'prediction_task': 'node', 'num_classes': 4},
#  'gnn': {'gnn_type': 'GCN',
#   'num_layers': 2,
#   'num_features': 3,
#   'hidden_dim': 16,
#   'embed_dim': 8},
#  'transformer': {'d_model': 128,
#   'n_heads': 4,
#   'dim_feedforward': 512,
#   'dropout': 0.3,
#   'num_layers': 4,
#   'activation_func': 'relu',
#   'num_encoder_layers': 4,
#   'max_input_len': 4}}

# %% [markdown]
# ## Dataset

# %%
import torch
from torch import nn, Tensor
from torch_geometric.data import Data, Dataset
import random

# %%
class CustomGraphDataset_graphLabel(Dataset):
    def __init__(self, num_graphs, max_nodes, max_edges, nr_node_features, nr_classes):
        self.num_graphs = num_graphs
        self.max_nodes = max_nodes
        self.max_edges = max_edges
        self.nr_node_features = nr_node_features
        self.data_list = []

        for _ in range(num_graphs):
            num_nodes = random.randint(1, max_nodes)
            num_edges = random.randint(0, min(num_nodes * (num_nodes - 1) // 2, max_edges))
            
            edge_index = torch.zeros((2, num_edges), dtype=torch.long)
            for i in range(num_edges):
                edge_index[0, i] = random.randint(0, num_nodes - 1)
                edge_index[1, i] = random.randint(0, num_nodes - 1)
            
            x = torch.rand((num_nodes, nr_node_features), dtype=torch.float)  # Node features (random for example)
            y = torch.tensor([random.randint(0, nr_classes)], dtype=torch.long)  # Graph label (binary for example)

            data = Data(x=x, edge_index=edge_index, y=y)
            self.data_list.append(data)

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, idx):
        return self.data_list[idx]

# %%
class CustomGraphDataset_nodeLabel(Dataset):
    def __init__(self, num_graphs, max_nodes, max_edges, nr_node_features, nr_classes):
        self.num_graphs = num_graphs
        self.max_nodes = max_nodes
        self.max_edges = max_edges
        self.nr_node_features = nr_node_features
        self.nr_classes = nr_classes
        self.data_list = []

        for _ in range(num_graphs):
            num_nodes = random.randint(1, max_nodes)
            num_edges = random.randint(0, min(num_nodes * (num_nodes - 1) // 2, max_edges))
            
            edge_index = torch.zeros((2, num_edges), dtype=torch.long)
            for i in range(num_edges):
                edge_index[0, i] = random.randint(0, num_nodes - 1)
                edge_index[1, i] = random.randint(0, num_nodes - 1)
            
            x = torch.rand((num_nodes, nr_node_features), dtype=torch.float)  # Node features (random for example)
            y = torch.randint(0, nr_classes, (num_nodes,), dtype=torch.long)  # Node labels

            data = Data(x=x, edge_index=edge_index, y=y)
            self.data_list.append(data)

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, idx):
        return self.data_list[idx]

# %%
num_graphs = 5
max_nodes_per_graph = 10
max_edges_per_graph = 10

graphLabel_custom_dataset = CustomGraphDataset_graphLabel(num_graphs, max_nodes_per_graph, max_edges_per_graph, cfg_dict['gnn']['num_features'], 3)

for i in range(num_graphs):
    data = graphLabel_custom_dataset[i]
    print(f"Graph {i + 1} - Nodes: {data.num_nodes}, Edges: {data.num_edges}, Label: {data.y.item()}")
# Out:
# Graph 1 - Nodes: 2, Edges: 1, Label: 2
# Graph 2 - Nodes: 7, Edges: 7, Label: 2
# Graph 3 - Nodes: 1, Edges: 0, Label: 1
# Graph 4 - Nodes: 7, Edges: 2, Label: 0
# Graph 5 - Nodes: 10, Edges: 2, Label: 0

# %%
nodeLabel_custom_dataset = CustomGraphDataset_nodeLabel(num_graphs, max_nodes_per_graph, max_edges_per_graph, cfg_dict['gnn']['num_features'], 3)

for i in range(num_graphs):
    data = nodeLabel_custom_dataset[i]
    print(f"Graph {i + 1} - Nodes: {data.num_nodes}, Edges: {data.num_edges}, Label: {data.y}")
# Out:
# Graph 1 - Nodes: 7, Edges: 3, Label: tensor([1, 0, 2, 0, 1, 1, 1])
# Graph 2 - Nodes: 10, Edges: 1, Label: tensor([2, 0, 2, 0, 1, 1, 2, 0, 0, 2])
# Graph 3 - Nodes: 9, Edges: 7, Label: tensor([2, 2, 0, 2, 0, 0, 1, 1, 1])
# Graph 4 - Nodes: 5, Edges: 6, Label: tensor([0, 0, 0, 0, 0])
# Graph 5 - Nodes: 2, Edges: 0, Label: tensor([2, 0])

# %%
for graph in nodeLabel_custom_dataset:
    print(graph)
# Out:
# Data(x=[7, 3], edge_index=[2, 3], y=[7])
# Data(x=[10, 3], edge_index=[2, 1], y=[10])
# Data(x=[9, 3], edge_index=[2, 7], y=[9])
# Data(x=[5, 3], edge_index=[2, 6], y=[5])
# Data(x=[2, 3], edge_index=[2, 0], y=[2])

# %% [markdown]
# ## Dataloader

# %%
from torch_geometric.loader import DataLoader

# %%
BATCH_SIZE = 1
train_loader = DataLoader(nodeLabel_custom_dataset.data_list, batch_size=BATCH_SIZE) # merges batch_size graphs from a PyG dataset

# %%
gnn_transformer_model = GNNTransformer(cfg_dict)
lr = 0.1
weight_decay = 5e-4
optimizer = torch.optim.Adam(gnn_transformer_model.parameters(), lr=lr, weight_decay=weight_decay)
criterion = torch.nn.CrossEntropyLoss()

accuracies_transformer, accuracies_gnn = train(train_loader, gnn_transformer_model, optimizer, criterion, cfg_dict, N_EPOCHS=20)
# Out:
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch   0 | Loss: 1.25 | GNN acc: 28.57% | Trans acc: 50.00%
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch   0 | Loss: 3.61 | GNN acc: 40.00% | Trans acc: 50.00%
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch   0 | Loss: 8.14 | GNN acc: 33.33% | Trans acc: 50.00%
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch   0 | Loss: 0.03 | GNN acc: 100.00% | Trans acc: 100.00%
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# Transformer Epoch   0 | Loss: 0.90 | GNN acc: 50.00% | Trans acc: 50.00%
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch   5 | Loss: 0.75 | GNN acc: 14.29% | Trans acc: 75.00%
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch   5 | Loss: 1.45 | GNN acc: 30.00% | Trans acc: 0.00%
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch   5 | Loss: 1.00 | GNN acc: 22.22% | Trans acc: 50.00%
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch   5 | Loss: 0.75 | GNN acc: 20.00% | Trans acc: 50.00%
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# Transformer Epoch   5 | Loss: 1.01 | GNN acc: 50.00% | Trans acc: 50.00%
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch  10 | Loss: 1.30 | GNN acc: 28.57% | Trans acc: 50.00%
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch  10 | Loss: 0.58 | GNN acc: 40.00% | Trans acc: 75.00%
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch  10 | Loss: 1.51 | GNN acc: 33.33% | Trans acc: 25.00%
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch  10 | Loss: 0.83 | GNN acc: 100.00% | Trans acc: 25.00%
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# Transformer Epoch  10 | Loss: 1.29 | GNN acc: 50.00% | Trans acc: 0.00%
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch  15 | Loss: 1.35 | GNN acc: 28.57% | Trans acc: 50.00%
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch  15 | Loss: 1.10 | GNN acc: 40.00% | Trans acc: 50.00%
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch  15 | Loss: 1.57 | GNN acc: 33.33% | Trans acc: 25.00%
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# Transformer Epoch  15 | Loss: 0.69 | GNN acc: 100.00% | Trans acc: 75.00%
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# Transformer Epoch  15 | Loss: 1.33 | GNN acc: 50.00% | Trans acc: 50.00%
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
# DataBatch(x=[7, 3], edge_index=[2, 3], y=[7], batch=[7], ptr=[2])
# GNN x:  torch.Size([7, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[10, 3], edge_index=[2, 1], y=[10], batch=[10], ptr=[2])
# GNN x:  torch.Size([10, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[9, 3], edge_index=[2, 7], y=[9], batch=[9], ptr=[2])
# GNN x:  torch.Size([9, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[5, 3], edge_index=[2, 6], y=[5], batch=[5], ptr=[2])
# GNN x:  torch.Size([5, 3])
# CLS + Normalized padded_h_node:  torch.Size([5, 1, 128])
# Padding mask:  torch.Size([1, 5])
# DataBatch(x=[2, 3], edge_index=[2, 0], y=[2], batch=[2], ptr=[2])
# GNN x:  torch.Size([2, 3])
# CLS + Normalized padded_h_node:  torch.Size([3, 1, 128])
# Padding mask:  torch.Size([1, 3])
