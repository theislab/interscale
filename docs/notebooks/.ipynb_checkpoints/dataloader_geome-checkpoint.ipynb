# %%
# %load_ext autoreload
# %autoreload 2

# %%
#import pytorch_lightning as pl
import torch
import anndata as ad
from geome import iterables, transforms, ann2data, datamodule
from geome.ann2data.by_category import Ann2DataByCategory
from geome.datamodule import GraphAnnDataModule
import numpy as np
import squidpy as sq
import matplotlib.pyplot as plt
import scanpy as sc

# %%
HE22_HUMAN_LUNG_DATA_PATH = '/lustre/groups/ml01/projects/2024_spatial_long_range_GT_francesca.drummer/unprocessed_data/he22_cosmx_human_lung.h5ad'

# %% [markdown]
# Follow guidelines from [geome notebooks](https://github.com/theislab/geome/blob/main/docs/notebooks/1_iterables_and_iterators.ipynb).
# [Contributing guide](https://scanpy.readthedocs.io/en/latest/dev/getting-set-up.html).

# %%
adata = sc.read_h5ad(HE22_HUMAN_LUNG_DATA_PATH)
adata
# Out:
# AnnData object with n_obs × n_vars = 771203 × 960
#     obs: 'AspectRatio', 'CenterX_global_px', 'CenterY_global_px', 'Width', 'Height', 'Mean.MembraneStain', 'Max.MembraneStain', 'Mean.PanCK', 'Max.PanCK', 'Mean.CD45', 'Max.CD45', 'Mean.CD3', 'Max.CD3', 'Mean.DAPI', 'Max.DAPI', 'niche', 'image_id', 'cell_ID', 'sex_ontology_term_id', 'assay_ontology_term_id', 'organism_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'tissue_type', 'condition_id', 'sample_id', 'donor_id', 'author_cell_type', 'library_key', 'region', 'assay', 'organism', 'sex', 'tissue', 'dataset', 'x', 'y', 'nicheformer_split', '_scvi_batch', '_scvi_labels', 'window'
#     var: 'level_0', 'index', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'log1p', 'niche', 'nicheformer_version', 'schema_version', 'title'
#     obsm: 'X_niche_0', 'X_niche_1', 'X_niche_2', 'X_niche_3', 'X_niche_4', 'X_pca', 'X_scvi', 'spatial'
# ...

# %%
GRAPH_ID = 'library_key' # obs variable to split adata on (create graphs from)

# %%
adata.obs[GRAPH_ID].cat.categories
# Out:
# Index([0, 1, 2, 3, 4, 5, 6, 7], dtype='int64')

# %%
adata.obs["donor_id"].cat.categories
# Out:
# Index(['Lung5', 'Lung6', 'Lung9', 'Lung12', 'Lung13'], dtype='object')

# %%
to_iterable: iterables.ToIterable = iterables.ToCategoryIterator(GRAPH_ID, axis="obs", preserve_categories=True)

# %%
# split_adatas = list(to_iterable(adata))  # split by cluster
# assert len(split_adatas) == len(adata.obs[GRAPH_ID].cat.categories) # ensure all clusters have their own adata
# split_adatas[:3]  # show first 3

# %%
# len(split_adatas)

# %% [markdown]
# ### Preprocess
#
# Prepare data format:
#
# 1. calculates addjacency matrix with spatial neighbours
# 2. select specific data points (?)

# %%
adj_matrix_loc = "obsp/adj_matrix"
fields = {
    "x": ["X"],
    "y": ["obs/author_cell_type"],
    "edge_index": ["uns/edge_index"],
}
category_to_iterate = "library_key"

# %%
preprocess = transforms.Compose(
    [
        transforms.Subset(key_value = {"donor_id": ["Lung5"]}, axis="obs"), 
        transforms.Categorize(keys=["donor_id", "author_cell_type", "region", "library_key"], axis="obs"),
        transforms.AddAdjMatrix(adj_matrix_loc, edge_index = True, overwrite=True, radius=30, coord_type='generic'),
        #transforms.AddEdgeIndex(adj_matrix_loc, edge_index_key="edge_index", overwrite=True)
    ]
)

# %%
d = {"donor_id": ["Lung5"]}
for k, v in d.items():
    print(k)
# Out:
# donor_id

# %% [markdown]
# ### Transform

# %%
transform = transforms.Compose(
    [
        transforms.AddDesignMatrix(
            "obs/author_cell_type",
            "obs/region",
            adj_matrix_loc,
            "design_matrix",
            overwrite=True,
        ),
        transforms.AddEdgeIndex(adj_matrix_loc, edge_index_key="edge_index", overwrite=True),
    ]
)

# %% [markdown]
# ### Create adata

# %%
a2d = ann2data.Ann2DataByCategory(
    fields=fields,
    category=category_to_iterate,
    preprocess=preprocess,
    transform=transform,
)

# %%
datas = list(a2d(adata))
datas[:3]
# Out:
# /home/icb/francesca.drummer/1-Projects/geome/src/geome/transforms/categorize.py:31: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   getattr(adata, self.axis)[key] = getattr(adata, self.axis)[key].astype("category")
# Spatial neighbours additional arguments: {'radius': 30, 'coord_type': 'generic'}
# [Data(x=[98000, 960], edge_index=[2, 6168], y=[98000, 18]),
#  Data(x=[105795, 960], edge_index=[2, 8250], y=[105795, 18]),
#  Data(x=[97806, 960], edge_index=[2, 6124], y=[97806, 18])]

# %%
torch.max(datas[1].x)
torch.min(datas[1].x)
# Out:
# tensor(0.)

# %% [markdown]
# ## Load from geome

# %%
from graph_transformer_long_range_niches.tl.load_config import Config  # noqa, register custom modules
from graph_transformer_long_range_niches.pp.datasets import prepare_geome_dataset
from graph_transformer_long_range_niches.pp.datamodule_geome import GraphAnnDataModule

# %%
default_path = '/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/default_configs.yaml'
cfg_path = '/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/he23_cosmx_human_lung_0_niche_gnn.yaml'

# %%
cfg = Config(cfg_path, default_path)
# Out:
# Load cfg file...
# ...

# %%
datas = prepare_geome_dataset(cfg)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 datas = prepare_geome_dataset(cfg)
#
# File ~/1-Projects/GT-long-range-niches/src/graph_transformer_long_range_niches/pp/datasets.py:32, in prepare_geome_dataset(cfg)
#      21 spatial_neigbors_kwargs = cfg.get('dataset/spatial_neigbors_kwargs')
#      23 preprocess = transforms.Compose(
#      24     [
#      25         transforms.Subset(key_value = subset_dict, axis="obs"),
#    (...)
#      29     ]
#      30 )
# ---> 32 print(adata)
#      34 transform = transforms.Compose(
#      35     [
#      36         transforms.AddDesignMatrix(
#    (...)
#      43     ]
#      44 )
#      46 a2d = ann2data.Ann2DataByCategory(
#      47     fields=fields,
#      48     category=category_to_iterate,
#      49     preprocess=preprocess,
#      50     transform=transform,
#      51 )
#
# ...

# %% [markdown]
# ### Datamodule with lightning.Dataset for PyTorch Geometric

# %%
from sklearn.model_selection import train_test_split

# %%
train_size = 0.8
val_size = 0.2
test_size = 0.0

# %%
train_ds, val_ds = train_test_split(datas, train_size=train_size, test_size=val_size+test_size, random_state=42)
if test_size > 0.0:
    val_ds, test_ds = train_test_split(val_ds, train_size=1-test_size, test_size=test_size, random_state=42)

# %%
print(len(train_ds), len(val_ds))
if test_size >0.0:
    print(len(test_ds))
# Out:
# 2 1

# %%
from torch_geometric.data.lightning import LightningDataset

# %%
dataset = LightningDataset(train_ds, val_ds)

# %%
for i in dataset.train_dataloader():
    print(i)
# Out:
# DataBatch(x=[105795, 960], edge_index=[2, 8250], y=[105795, 18], batch=[105795], ptr=[2])
# DataBatch(x=[97806, 960], edge_index=[2, 6124], y=[97806, 18], batch=[97806], ptr=[2])

# %% [markdown]
# ## Own Datamodule Definition

# %%
dm = GraphAnnDataModule(datas=datas, 
                            train_size=float(cfg.get('dataset/train_size')),
                            val_size=float(cfg.get('dataset/val_size')),
                            num_workers=1, 
                            batch_size=int(cfg.get('dataset/batch_size')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 dm = GraphAnnDataModule(datas=pyg_datas,
#       2                             train_size=float(cfg.get('dataset/train_size')),
#       3                             val_size=float(cfg.get('dataset/val_size')),
#       4                             num_workers=1,
#       5                             batch_size=int(cfg.get('dataset/batch_size')))
#
# NameError: name 'pyg_datas' is not defined

# %% [markdown]
# ## Old code
#
# from https://github.com/theislab/spatial-transformer/blob/c882e5a1a43b07a17ba8ea32fc59344cd01047cf/docs/notebooks/.ipynb_checkpoints/setup_spatialdata-checkpoint.ipynb#L39

# %%
def setup_spatialdata(
    data_path: str, 
    cell_type_id: str,
    graph_id: str, # which image does a cell belong to 
    layer_id: str,
    spatial_id: str,
    radius: int = 20, 
    ):
    
    adata = sc.read_h5ad(data_path)
    
    counts = adata.layers[layer_id]
    cell_types = adata.obs[cell_type_id]
    graph_id = adata.obs[graph_id]
    coordinates = adata.obsm[spatial_id]
        
    new_adata = ad.AnnData(counts, 
                      obs={'cell_type': list(cell_types.astype('category')), 'graph_id': list(graph_id.astype('category'))},
                      obsm={"spatial": coordinates}, 
                      dtype=np.int64)
    
    new_adata.obs_names = adata.obs_names
    new_adata.var_names = adata.var_names
    
    del adata
    
    # change image_id from floating to categorical
    new_adata.obs['graph_id'] = new_adata.obs['graph_id'].astype('category')
    
    #compute spatial connectivity matrix -> maybe this is already calculated with geome
    sq.gr.spatial_neighbors(new_adata, library_key = 'graph_id', coord_type = "generic", radius=radius)
    
    return new_adata

# %% [markdown]
# Does the geome dataloader assume a calculated spatial graph or can I adjust the radius etc?

# %%
def load_pyg_object(
    adata: ad.AnnData,
    node_label: str # cell_type or niche_label,
    ):

    """
        Creates a graph with node_label for each graph_id.

        Input:
            node_label: to be predicted node label (in adata.obs), saved as y in PyG object
            graph_id: nr ID assigning each node to a graph structure in the data
    """

    assert node_label in adata.obs_keys()
    
    fields = {
        f'features':['obs/{node_label}','obs/graph_id','obsm/design_matrix'],
        'labels':['X']
    }
    
    category_to_iterate = 'graph_id'
    
    preprocess = [
    lambda x,_: transforms.categorize_obs(x,['cell_type', 'graph_id']),
    lambda x,_: transforms.add_design_matrix(x,'obs/cell_type','obs/graph_id','design_matrix'),
    ]
    
    a2d = Ann2DataByCategory(
        fields=fields,
        category=category_to_iterate,
        preprocess=preprocess,
        yields_edge_index=False, 
    )
    
    return a2d(adata)

# %%
adata = setup_spatialdata(HE22_HUMAN_LUNG_DATA_PATH, 'author_cell_type', 'window', 'log1p', 'spatial')
adata
# Out:
# /home/icb/francesca.drummer/miniconda3/envs/exphormer/lib/python3.9/site-packages/anndata/_core/anndata.py:430: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# AnnData object with n_obs × n_vars = 771203 × 960
#     obs: 'cell_type', 'graph_id'
#     uns: 'spatial_neighbors'
#     obsm: 'spatial'
#     obsp: 'spatial_connectivities', 'spatial_distances'

# %%
adata.obs_keys()

# %%
from torch_geometric.utils import train_test_split_edges

pyg_adata = load_pyg_object(adata, 'cell_type')
pyg_adata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 from torch_geometric.utils import train_test_split_edges
# ----> 3 pyg_adata = load_pyg_object(adata, 'cell_type')
#       4 pyg_adata
#
# Cell In[31], line 28, in load_pyg_object(adata, node_label)
#      21 category_to_iterate = 'graph_id'
#      23 preprocess = [
#      24 lambda x,_: transforms.categorize_obs(x,['cell_type', 'graph_id']),
#      25 lambda x,_: transforms.add_design_matrix(x,'obs/cell_type','obs/graph_id','design_matrix'),
#      26 ]
# ---> 28 a2d = AnnData2DataByCategory(
#      29     fields=fields,
#      30     category=category_to_iterate,
#      31     preprocess=preprocess,
#      32     yields_edge_index=False,
#      33 )
#      35 return a2d(adata)
#
# NameError: name 'AnnData2DataByCategory' is not defined
