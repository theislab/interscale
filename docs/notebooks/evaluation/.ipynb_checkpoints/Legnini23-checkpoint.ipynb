# %% [markdown]
# # Legnini Evaluation

# %%
import scanpy as sc
import numpy as np

import InterScale as interscale
from InterScale.config import load_config
from graph_transformer_long_range_niches.pp import split_adata
from InterScale.tl import prepare_geome_dataset, check_and_update_cfg
from InterScale.geome_dataloader import GraphAnnDataModule
from InterScale.eval.gene_rank_analysis import predict_gene_r2, gene_rank_analysis

from pathlib import Path

# %%
pwd = "/dss/dsshome1/05/di93tig/1_projects/GT-long-range-niches/"

# %%
import sys
sys.path.insert(0, pwd)  # this depends on the notebook depth and must be adapted per notebook

from paths import LRZ_PROJECT

# %%
LRZ_PROJECT
# Out:
# '/dss/dssfs03/tumdss/pn36po/pn36po-dss-0002/di93tig/Projects/A3_InterScale/'

# %% [markdown]
# ## Load pretrained models

# %%
RESULTS_DIR = Path(LRZ_PROJECT, 'results/legnini23')

# %%
CFG = f"{pwd}src/config_files/Legnini23/legnini23_genes_sample_GlobalModel.yaml"
cfg = load_config(CFG)

# %%
adata = sc.read_h5ad(cfg.dataset.h5ad_data)
adata
# Out:
# AnnData object with n_obs × n_vars = 43762 × 88
#     obs: 'Cell', 'Area', 'x', 'y', 'sample', 'condition', 'organoid', 'obs_names', 'split'
#     var: 'gene_ids', 'feature_types'
#     obsm: 'spatial'
#     layers: 'log1p_norm', 'norm_ftsqrt', 'raw'

# %%
adata.obsm['spatial']
# Out:
# array([[2369.601, 1167.102],
#        [4930.774, 1151.607],
#        [2274.517, 1143.662],
#        ...,
#        [3625.728, 7206.087],
#        [3170.51 , 7260.791],
#        [3495.327, 7333.994]])

# %%
interscale.model.LocalModel._setup_anndata(adata = adata, prediction_task = cfg.dataset.prediction_task, layer_key = cfg.dataset.layer_key, sample_key_list = cfg.dataset.sample_key, prediction_obs =  cfg.dataset.prediction_obs, group_key = cfg.dataset.group_label, view_registry = False)
local_model = interscale.model.LocalModel.load(RESULTS_DIR, adata, cfg, local_component = True, global_component = False)
interscale.model.CombinedModel._setup_anndata(adata = adata, prediction_task = cfg.dataset.prediction_task, layer_key = cfg.dataset.layer_key, sample_key_list = cfg.dataset.sample_key, prediction_obs =  cfg.dataset.prediction_obs, group_key = cfg.dataset.group_label, view_registry = False)
combined_model = interscale.model.CombinedModel.load(RESULTS_DIR, adata, cfg, local_component = True, global_component = True)
# Out:
# Unclear checkpoint format. Attempting remapping anyway.
# State dict remapping applied. Source detected: unknown
# Unclear checkpoint format. Attempting remapping anyway.
# State dict remapping applied. Source detected: unknown
# Warning: Missing keys when loading state dict: ['global_module.cls_embedding', 'global_module.decoder.decoder.weight', 'global_module.decoder.decoder.bias', 'global_module.transformer_encoder.layers.0.self_attn.in_proj_weight', 'global_module.transformer_encoder.layers.0.self_attn.in_proj_bias', 'global_module.transformer_encoder.layers.0.self_attn.out_proj.weight', 'global_module.transformer_encoder.layers.0.self_attn.out_proj.bias', 'global_module.transformer_encoder.layers.0.linear1.weight', 'global_module.transformer_encoder.layers.0.linear1.bias', 'global_module.transformer_encoder.layers.0.linear2.weight', 'global_module.transformer_encoder.layers.0.linear2.bias', 'global_module.transformer_encoder.layers.0.norm1.weight', 'global_module.transformer_encoder.layers.0.norm1.bias', 'global_module.transformer_encoder.layers.0.norm2.weight', 'global_module.transformer_encoder.layers.0.norm2.bias', 'global_module.transformer_encoder.layers.1.self_attn.in_proj_weight', 'global_module.transformer_encoder.layers.1.self_attn.in_proj_bias', 'global_module.transformer_encoder.layers.1.self_attn.out_proj.weight', 'global_module.transformer_encoder.layers.1.self_attn.out_proj.bias', 'global_module.transformer_encoder.layers.1.linear1.weight', 'global_module.transformer_encoder.layers.1.linear1.bias', 'global_module.transformer_encoder.layers.1.linear2.weight', 'global_module.transformer_encoder.layers.1.linear2.bias', 'global_module.transformer_encoder.layers.1.norm1.weight', 'global_module.transformer_encoder.layers.1.norm1.bias', 'global_module.transformer_encoder.layers.1.norm2.weight', 'global_module.transformer_encoder.layers.1.norm2.bias', 'global_module.transformer_encoder.norm.weight', 'global_module.transformer_encoder.norm.bias', 'global_module.norm_input.weight', 'global_module.norm_input.bias']
# Warning: Unexpected keys when loading state dict: ['global_module.module.cls_embedding', 'global_module.module.transformer_encoder.layers.0.self_attn.in_proj_weight', 'global_module.module.transformer_encoder.layers.0.self_attn.in_proj_bias', 'global_module.module.transformer_encoder.layers.0.self_attn.out_proj.weight', 'global_module.module.transformer_encoder.layers.0.self_attn.out_proj.bias', 'global_module.module.transformer_encoder.layers.0.linear1.weight', 'global_module.module.transformer_encoder.layers.0.linear1.bias', 'global_module.module.transformer_encoder.layers.0.linear2.weight', 'global_module.module.transformer_encoder.layers.0.linear2.bias', 'global_module.module.transformer_encoder.layers.0.norm1.weight', 'global_module.module.transformer_encoder.layers.0.norm1.bias', 'global_module.module.transformer_encoder.layers.0.norm2.weight', 'global_module.module.transformer_encoder.layers.0.norm2.bias', 'global_module.module.transformer_encoder.layers.1.self_attn.in_proj_weight', 'global_module.module.transformer_encoder.layers.1.self_attn.in_proj_bias', 'global_module.module.transformer_encoder.layers.1.self_attn.out_proj.weight', 'global_module.module.transformer_encoder.layers.1.self_attn.out_proj.bias', 'global_module.module.transformer_encoder.layers.1.linear1.weight', 'global_module.module.transformer_encoder.layers.1.linear1.bias', 'global_module.module.transformer_encoder.layers.1.linear2.weight', 'global_module.module.transformer_encoder.layers.1.linear2.bias', 'global_module.module.transformer_encoder.layers.1.norm1.weight', 'global_module.module.transformer_encoder.layers.1.norm1.bias', 'global_module.module.transformer_encoder.layers.1.norm2.weight', 'global_module.module.transformer_encoder.layers.1.norm2.bias', 'global_module.module.transformer_encoder.norm.weight', 'global_module.module.transformer_encoder.norm.bias', 'global_module.module.norm_input.weight', 'global_module.module.norm_input.bias']
# /usr/local/lib/python3.10/dist-packages/scvi/data/fields/_base_field.py:63: UserWarning: adata.layers[log1p_norm] does not contain unnormalized count data. Are you sure this is what you want?
#   self.validate_field(adata)
# /dss/dsshome1/05/di93tig/1_projects/GT-long-range-niches/src/InterScale/model/base/_base_model.py:522: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_save_path)[SAVE_KEYS.MODEL_STATE_DICT_KEY]
# /usr/local/lib/python3.10/dist-packages/scvi/data/fields/_base_field.py:63: UserWarning: adata.layers[log1p_norm] does not contain unnormalized count data. Are you sure this is what you want?
#   self.validate_field(adata)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(

# %% [markdown]
# ## Inference

# %%
sub_adata = adata[adata.obs['condition'] == 'SHH']

# %%
result = local_model.get_model_output(sub_adata, prefix = 'local')
# Out:
# INFO     Received view of anndata, making copy.
# call new

# %%
result = combined_model.get_model_output(result, prefix = 'combined')
# Out:
# /usr/local/lib/python3.10/dist-packages/scvi/data/fields/_base_field.py:63: UserWarning: adata.layers[log1p_norm] does not contain unnormalized count data. Are you sure this is what you want?
#   self.validate_field(adata)
# call new
# 2001
# 1695
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 2001
# 1780

# %%
result
# Out:
# AnnData object with n_obs × n_vars = 31966 × 88
#     obs: 'Cell', 'Area', 'x', 'y', 'sample', 'condition', 'organoid', 'obs_names', 'split', '_scvi_sample_key_0', '_scvi_group_key', 'combined_cls'
#     var: 'gene_ids', 'feature_types'
#     uns: '_scvi_uuid', '_scvi_manager_uuid'
#     obsm: 'spatial', 'local_local_emb', 'local_decoder_weight', 'combined_local_emb', 'combined_global_emb', 'combined_attn_matrix', 'combined_decoder_weight'
#     layers: 'log1p_norm', 'norm_ftsqrt', 'raw', 'local_y_pred', 'combined_y_pred'

# %% [markdown]
# ## Gene Rank analysis

# %%
gene_rank_analysis(result,
                   layers_local_pred = 'local_y_pred',
                   layers_global_pred = 'combined_y_pred',
                   top_n = 5,
                   plot_result = True,
                   return_top_genes = True)
# Out:
# /dss/dsshome1/05/di93tig/1_projects/GT-long-range-niches/src/InterScale/eval/gene_rank_analysis.py:41: RuntimeWarning: invalid value encountered in log
#   r2_scores_log = [np.log(r2 + 1) for r2 in r2_scores if not np.isnan(r2)]
# /dss/dsshome1/05/di93tig/1_projects/GT-long-range-niches/src/InterScale/eval/gene_rank_analysis.py:41: RuntimeWarning: invalid value encountered in log
#   r2_scores_log = [np.log(r2 + 1) for r2 in r2_scores if not np.isnan(r2)]
# Top 5 genes for local_y_pred model:
#       gene        r2    r2_log  r2_rank
# 61  OLIG2  0.028057  0.027671     88.0
# 25  FOXA1  0.016264  0.016133     87.0
# 33  GRID2  0.008553  0.008517     86.0
# 24  FOSL2  0.006575  0.006553     85.0
# 23   FOSB  0.003611  0.003605     84.0
# Top 5 genes for combined_y_pred model:
#       gene        r2    r2_log  r2_rank
# 5     ARC  0.013323  0.013235     88.0
# 60  OLIG1 -0.001863 -0.001865     87.0
# 17   DBX1 -0.006256 -0.006275     86.0
# 57  NR4A2 -0.010104 -0.010155     85.0
# 74   SIX6 -0.012472 -0.012551     84.0
# (     gene  Local Rank  Global Rank  Rank Difference  Avg Rank
#  4    AQP4        29.0         69.0            -40.0      49.0
#  6    ARG1        14.0         54.0            -40.0      34.0
#  2    AIF1        37.0         71.0            -34.0      54.0
#  29   GAD1        40.0         73.0            -33.0      56.5
#  38  HPRT1        45.0         76.0            -31.0      60.5,
#         gene  Local Rank  Global Rank  Rank Difference  Avg Rank
#  24    FOSL2        85.0         15.0             70.0      50.0
#  3   ALDH1L1        71.0          6.0             65.0      38.5
#  20    EOMES        62.0         13.0             49.0      37.5
#  58    NR4A3        72.0         25.0             47.0      48.5
#  16     CUX2        77.0         32.0             45.0      54.5,
#       gene  Local Rank  Global Rank  Rank Difference  Avg Rank
#  25  FOXA1        87.0         79.0              8.0      83.0
#  60  OLIG1        78.0         87.0             -9.0      82.5
#  22    FOS        81.0         83.0             -2.0      82.0
#  73    SHH        80.0         81.0             -1.0      80.5
#  57  NR4A2        75.0         85.0            -10.0      80.0)
