# %% [markdown]
# # Dual Decoder Model
#
# Notebook showing how to load the DualDecoderModel (=two decoders, one each for local and global Model).

# %%
import pandas as pd
from pathlib import Path

# plotting libraries
import seaborn as sns
import matplotlib.pyplot as plt

import InterScale as interscale
from InterScale._paths import FIG_PATH
from InterScale.config import load_config
#from InterScale.pl.wandb import load_result_as_df, compute_mean_and_std, summary_df, plot_parameter_space

# %%
DUAL_LEGNINI = "/dss/dssfs03/tumdss/pn36po/pn36po-dss-0002/di93tig/Projects/A3_InterScale/results/legnini23/legnini23_regr_node_44_GCN_self-attn-transformer_model.ckpt"
DUAL_MELTON = "/dss/dssfs03/tumdss/pn36po/pn36po-dss-0002/di93tig/Projects/A3_InterScale/results/legnini23/legnini23_regr_node_44_GCN_self-attn-transformer_model.ckpt"

# %%
CFG_DUAL_LEGNINI = "/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/legnini23/regr_dual_combined.yaml"
CFG_DUAL_MELTON = "/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/config_files/melton25/regr_dual_combined.yaml"

# %% [markdown]
# ## 1. Load model

# %%
cfg = load_config(CFG_DUAL_LEGNINI)
cfg
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cfg = load_config(CFG_DUAL_LEGNINI)
#       2 cfg
#
# File /ictstr01/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/InterScale/config/__init__.py:68, in load_config(cfg_path)
#      65                 cfg = get_global_component_cfg(cfg, global_component_name)
#      67     # Now merge the full config file
# ---> 68     cfg.merge_from_file(cfg_path)
#      70 cfg.freeze()
#      71 return cfg
#
# File /ictstr01/groups/ml01/workspace/francesca.drummer/mamba/envs/GT_long_range_env/lib/python3.11/site-packages/yacs/config.py:213, in CfgNode.merge_from_file(self, cfg_filename)
#     211 with open(cfg_filename, "r") as f:
#     212     cfg = self.load_cfg(f)
# --> 213 self.merge_from_other_cfg(cfg)
#
# ...

# %%
adata = sc.read_h5ad(cfg.dataset.h5ad_data)
adata

# %%
interscale.model.DualDecoderCombinedModuleClass._setup_anndata(adata = adata, prediction_task = cfg.dataset.prediction_task, layer_key = cfg.dataset.layer_key, sample_key_list = cfg.dataset.sample_key, prediction_obs =  cfg.dataset.prediction_obs, group_key = cfg.dataset.group_label, view_registry = False)
combined_model = interscale.model.DualDecoderCombinedModuleClass.load(RESULTS_DIR, adata, cfg, model_name = model_name, local_component = True, global_component = True, wandb_save = True)
