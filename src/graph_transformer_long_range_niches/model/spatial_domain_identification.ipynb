# %%
from graph_transformer_long_range_niches._paths import HE22_HUMAN_LUNG_DATA_PATH

import scanpy as sc

import wandb
import pytorch_lightning as pl

# %% [markdown]
# # Spatial domain identification
#
# How well can we reconstruct the tissue in space with the trained model? Accuracy calculation from cell types might be different to actually reconstructing the tissue.
#
# Hypothesis:
#
# - GNNs tend to oversmooth so might create cell type islands
# - FCNN might be too random; no real spatial pattern
#
# Inspiration:
#
# Figure 1: Tang, Z. et al. SiGra: single-cell spatial elucidation through an image-augmented graph transformer. Nat Commun 14, 5618 (2023).

# %% [markdown]
# ## Load data and model

# %%
adata = sc.read_h5ad(HE22_HUMAN_LUNG_DATA_PATH)
adata

# %%
wandb.init()

# Download the Artifact
artifact = wandb.use_artifact("francesca-drummer/GTLongRange/he23_niche_gnntransformer:835744879", type="model")

# Load the Model
model_path = artifact.download()
# Assuming you have a PyTorch Lightning model saved as a .ckpt file
loaded_model = pl.load_from_checkpoint(model_path)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: francesca-drummer. Use `wandb login --relogin` to force relogin
# wandb version 0.17.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>/home/icb/francesca.drummer/1-Projects/GT-long-range-niches/src/graph_transformer_long_range_niches/model/wandb/run-20240513_171425-d4kdl9xn</code>
# Syncing run <strong><a href='https://wandb.ai/francesca-drummer/GT-long-range-niches-src_graph_transformer_long_range_niches_model/runs/d4kdl9xn' target="_blank">olive-durian-1</a></strong> to <a href='https://wandb.ai/francesca-drummer/GT-long-range-niches-src_graph_transformer_long_range_niches_model' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
# ...

# %% [markdown]
# ## Plot ground truth vs model output
