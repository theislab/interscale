# %%
import numpy as np

# %%
array1 = np.array([
    [3.625, 1.5625, 2., 2., 2.3125, 2.375, 2.5625, 1., 2.25, 2.125],
    [1.5, 1., 0.5, 3.5, 5., 0.5, 2., 4.5, 3., 3.],
    [8., 4.75, 10.5, 5., 10., 9., 6.25, 4., 2.25, 6.75],
    [7.75, 11.75, 9., 5., 10.25, 9.75, 9.25, 13., 11.25, 9.75],
    [4.5, 5., 5., 3.5, 6.5, 5., 5., 2., 2.5, 3.5],
    [5., 4., 4.5, 4., 3.5, 5.5, 5.5, 5.5, 2., 6.5],
    [8., 14.5, 3.5, 8., 4.75, 11.25, 7.75, 5.75, 10., 11.25],
    [1.65625, 1.71875, 1.625, 1.5, 1.46875, 0.71875, 1.59375, 1.75, 1.21875, 1.34375],
    [11., 11., 2.5, 8., 7., 13., 6., 6., 5., 7.5],
    [1.375, 1.96875, 0.4375, 1.375, 1.75, 1.25, 2.15625, 1.75, 0.53125, 1.96875]
])

array2 = np.array([
    [9., 2., 3., 3., 7., 6., 6., 1., 5., 5.],
    [3., 2., 1., 7., 10., 1., 4., 9., 6., 6.],
    [7., 3., 9., 4., 8., 7., 5., 2., 2., 5.],
    [4., 9., 6., 3., 6., 6., 5., 7., 7., 6.],
    [4., 6., 5., 6., 7., 4., 5., 1., 3., 4.],
    [5., 2., 5., 5., 2., 6., 3., 4., 4., 6.],
    [4., 9., 1., 4., 0., 5., 4., 2., 8., 6.],
    [5., 7., 4., 4., 3., 3., 7., 8., 7., 3.],
    [7., 10., 1., 7., 5., 10., 5., 4., 2., 5.],
    [5., 7., 1., 5., 6., 4., 8., 6., 2., 7.]
])

# %%
mean_1 = array1.mean(axis=0)
mean_2 = array2.mean(axis=0)
print(mean_1, mean_2)
# Out:
# [5.240625 5.725    3.95625  4.1875   5.253125 5.834375 4.80625  4.525
#  4.       5.36875 ] [5.3 5.7 3.6 4.8 5.4 5.2 5.2 4.4 4.6 5.3]

# %%
mean_1 = array1.mean()
mean_2 = array2.mean()
print(mean_1, mean_2)
# Out:
# 4.8896875 4.95

# %%
mean_1 == mean_2
# Out:
# np.False_

# %%
mean_1 == mean_2
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False])
